# %% [markdown]
# <a href="https://colab.research.google.com/github/twishi03/scRNA/blob/main/Tensor-cell2cell-PBMC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cell2cell
# Out:
# Collecting cell2cell
#   Downloading cell2cell-0.6.8-py3-none-any.whl (170 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.8/170.8 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from cell2cell) (1.22.4)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from cell2cell) (1.5.3)
# Requirement already satisfied: xlrd>=1.1 in /usr/local/lib/python3.10/dist-packages (from cell2cell) (2.0.1)
# Requirement already satisfied: openpyxl>=2.6.2 in /usr/local/lib/python3.10/dist-packages (from cell2cell) (3.0.10)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.10/dist-packages (from cell2cell) (3.1)
# Collecting matplotlib<=3.5.1,>=3.2.0 (from cell2cell)
#   Downloading matplotlib-3.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 63.9 MB/s eta 0:00:00
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from cell2cell) (0.12.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from cell2cell) (1.2.2)
# Collecting umap-learn (from cell2cell)
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 13.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from cell2cell) (4.65.0)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from cell2cell) (0.13.5)
# Collecting statannotations (from cell2cell)
#   Downloading statannotations-0.5.0-py3-none-any.whl (31 kB)
# Collecting tensorly==0.8.1 (from cell2cell)
#   Downloading tensorly-0.8.1-py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.7/229.7 kB 34.0 MB/s eta 0:00:00
# Collecting kneed (from cell2cell)
#   Downloading kneed-0.8.3-py3-none-any.whl (10 kB)
# Collecting scanpy (from cell2cell)
#   Downloading scanpy-1.9.3-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 104.9 MB/s eta 0:00:00
# Collecting gseapy==1.0.3 (from cell2cell)
#   Downloading gseapy-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from gseapy==1.0.3->cell2cell) (1.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from gseapy==1.0.3->cell2cell) (2.27.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<=3.5.1,>=3.2.0->cell2cell) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<=3.5.1,>=3.2.0->cell2cell) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<=3.5.1,>=3.2.0->cell2cell) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<=3.5.1,>=3.2.0->cell2cell) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<=3.5.1,>=3.2.0->cell2cell) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<=3.5.1,>=3.2.0->cell2cell) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<=3.5.1,>=3.2.0->cell2cell) (2.8.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl>=2.6.2->cell2cell) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->cell2cell) (2022.7.1)
# Collecting anndata>=0.7.4 (from scanpy->cell2cell)
#   Downloading anndata-0.9.1-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 16.6 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.10/dist-packages (from scanpy->cell2cell) (3.8.0)
# Requirement already satisfied: patsy in /usr/local/lib/python3.10/dist-packages (from scanpy->cell2cell) (0.5.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from scanpy->cell2cell) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scanpy->cell2cell) (1.2.0)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.10/dist-packages (from scanpy->cell2cell) (0.56.4)
# Collecting session-info (from scanpy->cell2cell)
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->cell2cell) (3.1.0)
# Collecting pynndescent>=0.5 (from umap-learn->cell2cell)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 96.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting seaborn>=0.11.0 (from cell2cell)
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 40.8 MB/s eta 0:00:00
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.41.0->scanpy->cell2cell) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.41.0->scanpy->cell2cell) (67.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy->scanpy->cell2cell) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->gseapy==1.0.3->cell2cell) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->gseapy==1.0.3->cell2cell) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->gseapy==1.0.3->cell2cell) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->gseapy==1.0.3->cell2cell) (3.4)
# Collecting stdlib_list (from session-info->scanpy->cell2cell)
#   Downloading stdlib_list-0.9.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 12.9 MB/s eta 0:00:00
# Building wheels for collected packages: umap-learn, pynndescent, session-info
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82816 sha256=4491725f380c536b579dccfe5e2d92eb1c148787f7f7325027a6d145215185cc
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55622 sha256=e9ad8f60fac539202796470271ee8f7a21b7659dccc71cd23e500dc0cf34e7c8
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8026 sha256=0b51f0cda63f4a96488a4c398a5b7832b260a19a1dbd7c429c369c424d8eaf35
#   Stored in directory: /root/.cache/pip/wheels/6a/aa/b9/eb5d4031476ec10802795b97ccf937b9bd998d68a9b268765a
# Successfully built umap-learn pynndescent session-info
# Installing collected packages: stdlib_list, tensorly, session-info, matplotlib, kneed, seaborn, pynndescent, gseapy, anndata, umap-learn, statannotations, scanpy, cell2cell
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# Successfully installed anndata-0.9.1 cell2cell-0.6.8 gseapy-1.0.3 kneed-0.8.3 matplotlib-3.5.1 pynndescent-0.5.10 scanpy-1.9.3 seaborn-0.11.2 session-info-1.0.0 statannotations-0.5.0 stdlib_list-0.9.0 tensorly-0.8.1 umap-learn-0.5.3

# %%
import cell2cell as c2c
import scanpy as sc

import pandas as pd
import numpy as np

from tqdm.auto import tqdm

# %matplotlib inline

# %% [markdown]
# # Data

# %% [markdown]
# **RNA-seq data**
#
# In this case is a published dataset of ~14000 IFN-beta treated and control PBMCs from 8 donors (GSE96583; see Kang et al.). (obtained from: https://scelvis.readthedocs.io/en/latest/tutorial_analysis.html)
#
# Download this dataset here: https://files.figshare.com/18037739/pbmc.h5ad

# %%
rnaseq = sc.read_h5ad('/content/pbmc.h5ad')

# %%
rnaseq
# Out:
# AnnData object with n_obs × n_vars = 13836 × 14053
#     obs: 'n_genes', 'n_counts', 'orig_ident', 'stim', 'cluster', 'Donor'
#     var: 'gene.mean', 'gene.dispersion', 'gene.dispersion.scaled'
#     uns: 'about_readme', 'about_short_title', 'about_title', 'marker_avg_logFC', 'marker_cluster', 'marker_gene', 'marker_p_val_adj'
#     obsm: 'X_tsne'

# %% [markdown]
# **Protein-Protein Interactions or Ligand-Receptor Pairs**
#
# In this case, we use a list of LR pairs published with CellChat (Jin et al. 2021, Nature Communications).

# %%
lr_pairs = pd.read_csv('https://raw.githubusercontent.com/LewisLabUCSD/Ligand-Receptor-Pairs/master/Human/Human-2020-Jin-LR-pairs.csv')

# %%
lr_pairs.head()
# Out:
#       interaction_name pathway_name ligand       receptor       agonist  \
# 0  TGFB1_TGFBR1_TGFBR2         TGFb  TGFB1      TGFbR1_R2  TGFb agonist
# 1  TGFB2_TGFBR1_TGFBR2         TGFb  TGFB2      TGFbR1_R2  TGFb agonist
# 2  TGFB3_TGFBR1_TGFBR2         TGFb  TGFB3      TGFbR1_R2  TGFb agonist
# 3  TGFB1_ACVR1B_TGFBR2         TGFb  TGFB1  ACVR1B_TGFbR2  TGFb agonist
# 4  TGFB1_ACVR1C_TGFBR2         TGFb  TGFB1  ACVR1C_TGFbR2  TGFb agonist
#
#         antagonist co_A_receptor             co_I_receptor        evidence  \
# 0  TGFb antagonist           NaN  TGFb inhibition receptor  KEGG: hsa04350
# 1  TGFb antagonist           NaN  TGFb inhibition receptor  KEGG: hsa04350
# 2  TGFb antagonist           NaN  TGFb inhibition receptor  KEGG: hsa04350
# 3  TGFb antagonist           NaN  TGFb inhibition receptor  PMID: 27449815
# 4  TGFb antagonist           NaN  TGFb inhibition receptor  PMID: 27449815
#
#            annotation       interaction_name_2 ligand_symbol receptor_symbol  \
# 0  Secreted Signaling  TGFB1 - (TGFBR1+TGFBR2)         TGFB1   TGFBR1&TGFBR2
# 1  Secreted Signaling  TGFB2 - (TGFBR1+TGFBR2)         TGFB2   TGFBR1&TGFBR2
# 2  Secreted Signaling  TGFB3 - (TGFBR1+TGFBR2)         TGFB3   TGFBR1&TGFBR2
# 3  Secreted Signaling  TGFB1 - (ACVR1B+TGFBR2)         TGFB1   ACVR1B&TGFBR2
# 4  Secreted Signaling  TGFB1 - (ACVR1C+TGFBR2)         TGFB1   ACVR1C&TGFBR2
#
#     ligand_ensembl                 receptor_ensembl   interaction_symbol  \
# 0  ENSG00000105329  ENSG00000106799&ENSG00000163513  TGFB1^TGFBR1&TGFBR2
# 1  ENSG00000092969  ENSG00000106799&ENSG00000163513  TGFB2^TGFBR1&TGFBR2
# 2  ENSG00000119699  ENSG00000106799&ENSG00000163513  TGFB3^TGFBR1&TGFBR2
# 3  ENSG00000105329  ENSG00000135503&ENSG00000163513  TGFB1^ACVR1B&TGFBR2
# 4  ENSG00000105329  ENSG00000123612&ENSG00000163513  TGFB1^ACVR1C&TGFBR2
#
#                                interaction_ensembl
# 0  ENSG00000105329^ENSG00000106799&ENSG00000163513
# 1  ENSG00000092969^ENSG00000106799&ENSG00000163513
# 2  ENSG00000119699^ENSG00000106799&ENSG00000163513
# 3  ENSG00000105329^ENSG00000135503&ENSG00000163513
# 4  ENSG00000105329^ENSG00000123612&ENSG00000163513

# %%
# interaction columns:
int_columns = ('ligand_symbol', 'receptor_symbol')

# %% [markdown]
# Remove bidirectionality in the list of ligand-receptor pairs. That is, remove repeated interactions where both interactions are the same but in different order:
#
# From this list:
#
# | Ligand | Receptor |
# | --- | --- |
# | Protein A | Protein B |
# | Protein B | Protein A |
#
# We will have:
#
# | Ligand | Receptor |
# | --- | --- |
# | Protein A | Protein B |

# %%
lr_pairs = c2c.preprocessing.ppi.remove_ppi_bidirectionality(ppi_data=lr_pairs,
                                                             interaction_columns=int_columns
                                                             )
# Out:
# Removing bidirectionality of PPI network

# %%
lr_pairs.shape
# Out:
# (1988, 17)

# %% [markdown]
# **Generate a dictionary with function info for each LR pairs. Keys are LIGAND_NAME^RECEPTOR_NAME and values are the function in the annotation column in the dataframe containing ligand-receptor pairs.**

# %%
ppi_functions = dict()

for idx, row in lr_pairs.iterrows():
    ppi_label = row[int_columns[0]] + '^' + row[int_columns[1]]
    ppi_functions[ppi_label] = row['annotation']

# %% [markdown]
# **Metadata**
#
# Metadata for the single cells

# %%
meta = rnaseq.obs.copy()

# %%
meta.head()
# Out:
#                        n_genes  n_counts orig_ident  stim    cluster     Donor
# index
# CTRL_AAACATACATTTCC.1    878.0    3018.0       CTRL  CTRL  CD14 Mono  SNG-1016
# CTRL_AAACATACCAGAAA.1    713.0    2481.0       CTRL  CTRL  CD14 Mono  SNG-1256
# CTRL_AAACATACCTCGCT.1    850.0    3420.0       CTRL  CTRL  CD14 Mono  SNG-1256
# CTRL_AAACATACGGCATT.1    558.0    1582.0       CTRL  CTRL  CD14 Mono  SNG-1015
# CTRL_AAACATTGCTTCGC.1    669.0    2536.0       CTRL  CTRL  CD14 Mono  SNG-1256

# %% [markdown]
# # Tensor-cell2cell Analysis

# %% [markdown]
# **Organize data to create tensor**

# %% [markdown]
# **In this dataset, contexts correspond to donors in both conditions before and after treatment**, so we need to arrange their expression matrices and then preprocess them.

# %% [markdown]
# First, generate a dictionary indicating what condition is associated to each sample

# %%
meta['Context'] = meta.apply(lambda row: row['Donor'] + '_' + row['stim'], axis=1)

context_dict = dict()

for stim, df in meta.groupby('stim'):
    for donor in df.Context.unique():
        context_dict[donor] = stim

# %%
context_dict
# Out:
# {'SNG-1016_CTRL': 'CTRL',
#  'SNG-1256_CTRL': 'CTRL',
#  'SNG-1015_CTRL': 'CTRL',
#  'SNG-101_CTRL': 'CTRL',
#  'SNG-1488_CTRL': 'CTRL',
#  'SNG-1244_CTRL': 'CTRL',
#  'SNG-1039_CTRL': 'CTRL',
#  'SNG-107_CTRL': 'CTRL',
#  'SNG-101_STIM': 'STIM',
#  'SNG-1016_STIM': 'STIM',
#  'SNG-1244_STIM': 'STIM',
#  'SNG-1488_STIM': 'STIM',
#  'SNG-1015_STIM': 'STIM',
#  'SNG-1256_STIM': 'STIM',
#  'SNG-1039_STIM': 'STIM',
#  'SNG-107_STIM': 'STIM'}

# %% [markdown]
# Sort contexts to have them all together by condition, but donors in the same order within each condition

# %%
context_names = meta.Donor.unique().tolist()
context_names = [c + '_CTRL' for c in context_names] + [c + '_STIM' for c in context_names]

# %%
context_names
# Out:
# ['SNG-1016_CTRL',
#  'SNG-1256_CTRL',
#  'SNG-1015_CTRL',
#  'SNG-101_CTRL',
#  'SNG-1488_CTRL',
#  'SNG-1244_CTRL',
#  'SNG-1039_CTRL',
#  'SNG-107_CTRL',
#  'SNG-1016_STIM',
#  'SNG-1256_STIM',
#  'SNG-1015_STIM',
#  'SNG-101_STIM',
#  'SNG-1488_STIM',
#  'SNG-1244_STIM',
#  'SNG-1039_STIM',
#  'SNG-107_STIM']

# %% [markdown]
# **Generate list of RNA-seq data for each context**

# %%
rnaseq_matrices = []

for context in tqdm(context_names):
        meta_context = meta.loc[meta['Context'] == context]
        cells = list(meta_context.index)

        meta_context.index.name = 'barcode'
        tmp_data = rnaseq[cells]
        # Keep genes in each sample with at least 3 single cells expressing it
        sc.pp.filter_genes(tmp_data, min_cells=3)

        # Aggregate gene expression of single cells into cell types
        exp_df = c2c.preprocessing.aggregate_single_cells(rnaseq_data=tmp_data.to_df(),
                                                          metadata=meta_context,
                                                          barcode_col='barcode',
                                                          celltype_col='cluster',
                                                          method='nn_cell_fraction',
                                                         )

        rnaseq_matrices.append(exp_df)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number

# %% [markdown]
# **Build 4D-Communication Tensor**
#
# ```how='inner'``` is used to keep only cell types and genes that are across all contexts.
#
# ```complex_sep='&'``` is used to specify that the list of ligand-receptor pairs contains protein complexes and that subunits are separated by '&'. If the list does not have complexes, use ```complex_sep=None``` instead.

# %%
tensor = c2c.tensor.InteractionTensor(rnaseq_matrices=rnaseq_matrices,
                                      ppi_data=lr_pairs,
                                      context_names=context_names,
                                      how='inner',
                                      complex_sep='&',
                                      interaction_columns=int_columns,
                                      communication_score='expression_mean',
                                     )
# Out:
# Getting expression values for protein complexes
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
# ...
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# /usr/local/lib/python3.10/dist-packages/cell2cell/preprocessing/rnaseq.py:179: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = tmp_rna.loc[v, :]
# Building tensor for the provided context

# %% [markdown]
# (# Contexts, # LR pairs, # Sender cell types, # Receiver cell types) contained in the tensor, after all the preprocessing

# %%
tensor.tensor.shape
# Out:
# (16, 46, 12, 12)

# %% [markdown]
# **Generate a list containing metadata for each tensor order/dimension - Later used for coloring factor plots**

# %%
meta_tf = c2c.tensor.generate_tensor_metadata(interaction_tensor=tensor,
                                              metadata_dicts=[context_dict, ppi_functions, None, None],
                                              fill_with_order_elements=True
                                             )

# %% [markdown]
# **Elbow analysis for selecting Rank for Tensor-Factorization**

# %%
import numpy as np

# %%
fig, error = tensor.elbow_rank_selection(upper_rank=25,
                                         runs=10,
                                         init='random', # If it outputs a memory error, replace by 'random'
                                         automatic_elbow=True,
                                         random_state=888,
                                         filename=None # Put a path (e.g. ./Elbow.png) to save the figure
                                        )
# Out:
# 100%|██████████| 25/25 [05:22<00:00, 12.91s/it]
# The rank at the elbow is: 8

# %% [markdown]
# **Tensor decomposition**

# %%
tensor.compute_tensor_factorization(rank=tensor.rank,
                                    init='random', # If it outputs a memory error, replace by 'random'
                                    random_state=888)

# %% [markdown]
# # Results

# %% [markdown]
# **Plot factors**

# %% [markdown]
# Color palettes for each dimension

# %%
cmaps = ['plasma', 'Dark2_r', 'tab20', 'tab20']

# %% [markdown]
# Plot factor loadings

# %%
fig, axes = c2c.plotting.tensor_factors_plot(interaction_tensor=tensor,
                                             metadata = meta_tf,
                                             sample_col='Element',
                                             group_col='Category',
                                             meta_cmaps=cmaps,
                                             fontsize=14,
                                             filename='/content/TF.png' # Put a path (e.g. ./TF.png) to save the figure
                                            )

# %% [markdown]
# **Top-5 LR pairs in each factor**

# %%
for i in range(tensor.rank):
    print(tensor.get_top_factor_elements('Ligand-Receptor Pairs', 'Factor {}'.format(i+1), 5))
    print('')
# Out:
# APP^CD74           0.464459
# ANXA1^FPR1         0.423217
# ANXA1^FPR2         0.390493
# ANXA1^FPR2&FPR3    0.388237
# THBS1^CD47         0.264761
# Name: Factor 1, dtype: float64
#
# ANXA1^FPR1         0.475486
# ANXA1^FPR2         0.468468
# ANXA1^FPR2&FPR3    0.464827
# LGALS9^PTPRC       0.312715
# LGALS9^CD44        0.308674
# Name: Factor 2, dtype: float64
#
# CD99^PILRA       0.460467
# LGALS9^HAVCR2    0.346936
# CCL5^CCR1        0.266100
# CCL7^CCR1        0.250548
# CCL3L1^CCR1      0.242871
# Name: Factor 3, dtype: float64
#
# CXCL10^CXCR3    0.469166
# CD86^CD28       0.347517
# CCL3^CCR5       0.328124
# CCL3^CCR1       0.326484
# LGALS9^PTPRC    0.279899
# Name: Factor 4, dtype: float64
#
# MIF^CD74&CXCR4    0.537267
# APP^CD74          0.475637
# MIF^CD74&CD44     0.469456
# LGALS9^CD44       0.302503
# LGALS9^PTPRC      0.208938
# Name: Factor 5, dtype: float64
#
# CCL5^CCR5          0.641034
# CCL5^CCR1          0.640764
# PF4^CXCR3          0.211539
# ANXA1^FPR2&FPR3    0.158174
# ANXA1^FPR2         0.154480
# Name: Factor 6, dtype: float64
#
# HLA-DMA^CD4      0.702232
# LGALS9^CD44      0.353689
# LGALS9^PTPRC     0.314911
# CD86^CD28        0.229760
# LGALS9^HAVCR2    0.209955
# Name: Factor 7, dtype: float64
#
# SELPLG^SELL     0.639110
# CXCL10^CXCR3    0.430750
# THBS1^CD47      0.368527
# APP^CD74        0.329564
# LGALS9^PTPRC    0.287948
# Name: Factor 8, dtype: float64

# %% [markdown]
# **Export an excel with all loadings**

# %%
#tensor.export_factor_loadings('Loadings.xlsx')

# %% [markdown]
# <a href="https://colab.research.google.com/github/twishi03/scRNA/blob/main/scLabel_Transfer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://github.com/mousepixels/sanbomics_scripts/blob/main/scvi_label_transfer.ipynb

# %%
# !pip install scanpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scanpy
#   Downloading scanpy-1.9.2-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 22.9 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.8/dist-packages (from scanpy) (3.0)
# Requirement already satisfied: patsy in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.5.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.8/dist-packages (from scanpy) (5.5.0)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.7.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.2.0)
# Collecting umap-learn>=0.3.10
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: seaborn in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.11.2)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.3.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from scanpy) (4.64.1)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.56.4)
# Collecting session-info
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.21.6)
# Collecting anndata>=0.7.4
#   Downloading anndata-0.8.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.1/96.1 KB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.12.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from scanpy) (23.0)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.0.2)
# Collecting matplotlib>=3.4
#   Downloading matplotlib-3.7.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 96.6 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.8/dist-packages (from scanpy) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (5.10.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (7.1.2)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 KB 34.2 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 KB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy) (6.0.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0->scanpy) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->scanpy) (3.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy->scanpy) (1.15.0)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 43.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting stdlib_list
#   Downloading stdlib_list-0.8.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 KB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.4->scanpy) (3.13.0)
# Building wheels for collected packages: umap-learn, session-info, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=68c982a2a17dc530cce72b56d60e546b13add0b0102e8a4e235e7e5b9047ece6
#   Stored in directory: /root/.cache/pip/wheels/a9/3a/67/06a8950e053725912e6a8c42c4a3a241410f6487b8402542ea
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8046 sha256=4218d2c45106400d98a95f19f5694e539f1e8e2d4ff260a3b39bec12d8cf0e33
#   Stored in directory: /root/.cache/pip/wheels/5c/1b/4d/111d73980c5c6a8e5e5905a19eccc34296cb359cac54c6c5b9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55513 sha256=ca5eea2b7165209d2993d4161a97c8e9bf7fe90ab36342daefee0933939d6a58
#   Stored in directory: /root/.cache/pip/wheels/1c/63/3a/29954bca1a27ba100ed8c27973a78cb71b43dc67aed62e80c3
# Successfully built umap-learn session-info pynndescent
# Installing collected packages: stdlib_list, session-info, fonttools, contourpy, matplotlib, pynndescent, anndata, umap-learn, scanpy
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# Successfully installed anndata-0.8.0 contourpy-1.0.7 fonttools-4.38.0 matplotlib-3.7.0 pynndescent-0.5.8 scanpy-1.9.2 session-info-1.0.0 stdlib_list-0.8.0 umap-learn-0.5.3

# %%
# !pip install scvi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scvi
#   Using cached scvi-0.6.8-py2.py3-none-any.whl (158 kB)
# Requirement already satisfied: scanpy>=1.4.6 in /usr/local/lib/python3.8/dist-packages (from scvi) (1.9.2)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.8/dist-packages (from scvi) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.20.3 in /usr/local/lib/python3.8/dist-packages (from scvi) (1.0.2)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.8/dist-packages (from scvi) (1.13.1+cu116)
# Requirement already satisfied: anndata>=0.7 in /usr/local/lib/python3.8/dist-packages (from scvi) (0.8.0)
# Collecting scikit-misc>=0.1.3
#   Using cached scikit_misc-0.1.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (8.8 MB)
# Requirement already satisfied: matplotlib>=3.1.2 in /usr/local/lib/python3.8/dist-packages (from scvi) (3.7.0)
# Requirement already satisfied: hyperopt==0.1.2 in /usr/local/lib/python3.8/dist-packages (from scvi) (0.1.2)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.8/dist-packages (from scvi) (1.21.6)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.8/dist-packages (from scvi) (4.64.1)
# Requirement already satisfied: xlrd>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from scvi) (1.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from scvi) (3.1.0)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from hyperopt==0.1.2->scvi) (0.16.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.8/dist-packages (from hyperopt==0.1.2->scvi) (4.3.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from hyperopt==0.1.2->scvi) (3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from hyperopt==0.1.2->scvi) (1.7.3)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from hyperopt==0.1.2->scvi) (1.15.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.8/dist-packages (from anndata>=0.7->scvi) (23.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.8/dist-packages (from anndata>=0.7->scvi) (5.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->scvi) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->scvi) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->scvi) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->scvi) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->scvi) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->scvi) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->scvi) (5.10.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->scvi) (7.1.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->scvi) (2022.7.1)
# Requirement already satisfied: patsy in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.4.6->scvi) (0.5.3)
# Requirement already satisfied: session-info in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.4.6->scvi) (1.0.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.4.6->scvi) (1.2.0)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.4.6->scvi) (0.56.4)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.4.6->scvi) (0.12.2)
# Requirement already satisfied: umap-learn>=0.3.10 in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.4.6->scvi) (0.5.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.4.6->scvi) (0.11.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.3->scvi) (3.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.3->scvi) (4.5.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.1.2->scvi) (3.13.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy>=1.4.6->scvi) (6.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy>=1.4.6->scvi) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy>=1.4.6->scvi) (0.39.1)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.8/dist-packages (from umap-learn>=0.3.10->scanpy>=1.4.6->scvi) (0.5.8)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from pymongo->hyperopt==0.1.2->scvi) (2.3.0)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.8/dist-packages (from session-info->scanpy>=1.4.6->scvi) (0.8.0)
# Installing collected packages: scikit-misc, scvi
# Successfully installed scikit-misc-0.1.4 scvi-0.6.8

# %%
import scanpy as sc

# %%
import scvi
# Out:
# /usr/local/lib/python3.8/dist-packages/scvi/__init__.py:31: DeprecationWarning: scvi is deprecated, please uninstall scvi via `pip uninstall scvi` and install the new scvi-tools package at github.com/YosefLab/scvi-tools
#   warnings.warn(deprecation_msg, DeprecationWarning)

# %%
ref_data = sc.read_h5ad('/content/pbmcref.h5ad')

# %%
ref_data.obs
# Out:
#                        n_genes  n_counts orig_ident  stim    cluster     Donor
# index
# CTRL_AAACATACATTTCC.1    878.0    3018.0       CTRL  CTRL  CD14 Mono  SNG-1016
# CTRL_AAACATACCAGAAA.1    713.0    2481.0       CTRL  CTRL  CD14 Mono  SNG-1256
# CTRL_AAACATACCTCGCT.1    850.0    3420.0       CTRL  CTRL  CD14 Mono  SNG-1256
# CTRL_AAACATACGGCATT.1    558.0    1582.0       CTRL  CTRL  CD14 Mono  SNG-1015
# CTRL_AAACATTGCTTCGC.1    669.0    2536.0       CTRL  CTRL  CD14 Mono  SNG-1256
# ...                        ...       ...        ...   ...        ...       ...
# STIM_TCCCGAACTTCGTT.1    702.0    4222.0       STIM  STIM      Eryth  SNG-1015
# STIM_TCGGACCTATCAGC.1    502.0    2050.0       STIM  STIM      Eryth   SNG-101
# STIM_TGACGCCTCTTGTT.1    899.0    7168.0       STIM  STIM      Eryth  SNG-1015
# STIM_TGGTCAGACAAGCT.1    550.0    4225.0       STIM  STIM      Eryth  SNG-1039
# STIM_TGTGAGTGTCTTAC.1    607.0    2804.0       STIM  STIM      Eryth  SNG-1256
#
# [13836 rows x 6 columns]

# %%
adata = sc.read_h5ad('/content/pbmc.h5ad')
adata.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [AAACCCAAGGAGAGTA-1, AAACGCTTCAGCCCAG-1, AAAGAACAGACGACTG-1, AAAGAACCAATGGCAG-1, AAAGAACGTCTGCAAT-1, AAAGGATAGTAGACAT-1, AAAGGATCACCGGCTA-1, AAAGGATTCAGCTTGA-1, AAAGGATTCCGTTTCG-1, AAAGGGCTCATGCCCT-1, AAAGGGCTCCGTAGGC-1, AAAGGTACAACTGCTA-1, AAAGTCCAGCGGGTTA-1, AAAGTCCCACCAGCCA-1, AAAGTGATCGTACACA-1, AAATGGAAGCCGCTTG-1, AAATGGACAATGCTCA-1, AAATGGAGTACCGCGT-1, AAATGGATCCTATTTG-1, AACAAAGGTGATGAAT-1, AACAACCAGTAGTCCT-1, AACAACCCACGCTATA-1, AACAAGAGTTATAGAG-1, AACAGGGGTGGGAGAG-1, AACCAACAGCTTGTTG-1, AACCCAACAACTGATC-1, AACCCAAGTGGGCTTC-1, AACCCAATCTTACCGC-1, AACCTGACATCCTATT-1, AACCTTTGTTTCGGCG-1, AACGAAAAGGTTGGTG-1, AACGAAACAGCGTTTA-1, AACGAAATCCATTTAC-1, AACGGGAGTCGCTCGA-1, AACGTCAAGACGCCCT-1, AAGAACAAGACCATTC-1, AAGAACAAGCCTCAGC-1, AAGAACATCTTGCAAG-1, AAGACAACACTTCAGA-1, AAGACAACAGATCACT-1, AAGACAATCCGCGAGT-1, AAGCATCAGGTCCGAA-1, AAGCATCCAGTCTTCC-1, AAGCGTTCACTGATTG-1, AAGCGTTTCGCTATTT-1, AAGGTAAAGGAAGTAG-1, AAGGTAAAGGCCACCT-1, AAGGTAAGTCCTTAAG-1, AAGTACCAGCGCCTTG-1, AAGTACCAGCTCCATA-1, AAGTACCCAAAGAACT-1, AAGTGAACATCAGCAT-1, AAGTGAATCGGAAGGT-1, AAGTTCGAGGATACAT-1, AAGTTCGGTCAACACT-1, AATCGACGTGAGACGT-1, AATGACCGTGTCATCA-1, AATGGAACACTCATAG-1, AATGGAATCTGATGGT-1, AATTCCTTCCATTGGA-1, ACAAAGAAGCCTCAAT-1, ACAAAGAGTTCCATTT-1, ACAACCATCTATCCAT-1, ACAACCATCTGCCCTA-1, ACAAGCTGTAGGTCAG-1, ACACCAAAGAGTCAGC-1, ACACGCGGTGTTGCCG-1, ACACGCGTCACCTCGT-1, ACACGCGTCGCCGTGA-1, ACACTGATCACTGATG-1, ACACTGATCTTTCCGG-1, ACAGAAAAGTATTAGG-1, ACAGAAACACCAGCGT-1, ACAGCCGTCGCTGTTC-1, ACATCCCCACAAATGA-1, ACATCCCGTAAGATTG-1, ACATCGATCTAAGAAG-1, ACATCGATCTGAGAGG-1, ACATCGATCTTGGGCG-1, ACATGCAGTTGCTTGA-1, ACATTTCGTGCCGAAA-1, ACATTTCGTTTCTTAC-1, ACCACAAAGGCCTTGC-1, ACCACAAGTCTGTGGC-1, ACCATTTCATTGGGAG-1, ACCCAAAGTTGGGAAC-1, ACCCTTGGTATCGTAC-1, ACCCTTGTCATTTCGT-1, ACCTACCCAACGGTAG-1, ACCTGAACATGAGAAT-1, ACCTGTCTCAAGTCTG-1, ACCTGTCTCTCAACGA-1, ACGATCAGTCGTTCAA-1, ACGATCATCCACGGAC-1, ACGATCATCCGTTGGG-1, ACGCACGAGAGAGTGA-1, ACGGTCGTCACTACGA-1, ACGGTTAAGTGCTCAT-1, ACGTAACAGGTGCTTT-1, ACGTAACTCATATGGC-1, ...]
#
# [1087 rows x 0 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1087 × 15099

# %%
adata.var_names_make_unique()

# %%
adata = adata.concatenate(ref_data)
adata.obs
# Out:
# /usr/local/lib/python3.8/dist-packages/anndata/_core/merge.py:942: UserWarning: Only some AnnData objects have `.raw` attribute, not concatenating `.raw` attributes.
#   warn(
# /usr/local/lib/python3.8/dist-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
#                          n_genes  n_counts orig_ident  stim cluster     Donor  \
# AAACCCAAGGAGAGTA-1-0         NaN       NaN        NaN   NaN     NaN       NaN
# AAACGCTTCAGCCCAG-1-0         NaN       NaN        NaN   NaN     NaN       NaN
# AAAGAACAGACGACTG-1-0         NaN       NaN        NaN   NaN     NaN       NaN
# AAAGAACCAATGGCAG-1-0         NaN       NaN        NaN   NaN     NaN       NaN
# AAAGAACGTCTGCAAT-1-0         NaN       NaN        NaN   NaN     NaN       NaN
# ...                          ...       ...        ...   ...     ...       ...
# STIM_TCCCGAACTTCGTT.1-1    702.0    4222.0       STIM  STIM   Eryth  SNG-1015
# STIM_TCGGACCTATCAGC.1-1    502.0    2050.0       STIM  STIM   Eryth   SNG-101
# STIM_TGACGCCTCTTGTT.1-1    899.0    7168.0       STIM  STIM   Eryth  SNG-1015
# STIM_TGGTCAGACAAGCT.1-1    550.0    4225.0       STIM  STIM   Eryth  SNG-1039
# STIM_TGTGAGTGTCTTAC.1-1    607.0    2804.0       STIM  STIM   Eryth  SNG-1256
#
#                         batch
# AAACCCAAGGAGAGTA-1-0        0
# AAACGCTTCAGCCCAG-1-0        0
# AAAGAACAGACGACTG-1-0        0
# AAAGAACCAATGGCAG-1-0        0
# AAAGAACGTCTGCAAT-1-0        0
# ...                       ...
# STIM_TCCCGAACTTCGTT.1-1     1
# STIM_TCGGACCTATCAGC.1-1     1
# STIM_TGACGCCTCTTGTT.1-1     1
# STIM_TGGTCAGACAAGCT.1-1     1
# STIM_TGTGAGTGTCTTAC.1-1     1
#
# [14923 rows x 7 columns]

# %%
adata.layers["counts"] = adata.X.copy()
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata

sc.pp.highly_variable_genes(adata, flavor = 'seurat_v3', n_top_genes=2000,
                            layer = "counts", batch_key="batch", subset = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/scanpy/preprocessing/_highly_variable_genes.py:62: UserWarning: `flavor='seurat_v3'` expects raw count data, but non-integers were found.
#   warnings.warn(

# %%
# !pip install scvi-tools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scvi-tools in /usr/local/lib/python3.8/dist-packages (0.20.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (1.7.3)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (1.3.5)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (1.21.6)
# Requirement already satisfied: tqdm>=4.56.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (4.64.1)
# Requirement already satisfied: openpyxl>=3.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (3.0.10)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (1.13.1+cu116)
# Requirement already satisfied: flax in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (0.6.4)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (3.1.0)
# Requirement already satisfied: torchmetrics>=0.11.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (0.11.1)
# Requirement already satisfied: anndata>=0.7.5 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (0.8.0)
# Requirement already satisfied: docrep>=0.3.2 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (0.3.2)
# Requirement already satisfied: chex in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (0.1.6)
# Requirement already satisfied: pyro-ppl>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (1.8.4)
# Requirement already satisfied: jax>=0.3 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (0.4.4)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (0.4.4)
# Requirement already satisfied: scikit-learn>=0.21.2 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (1.0.2)
# Requirement already satisfied: numpyro in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (0.11.0)
# Requirement already satisfied: mudata>=0.1.2 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (0.2.1)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (13.3.1)
# Requirement already satisfied: optax in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (0.1.4)
# Requirement already satisfied: pytorch-lightning<1.10.0,>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (1.9.2)
# Requirement already satisfied: ml-collections>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (0.1.1)
# Requirement already satisfied: natsort in /usr/local/lib/python3.8/dist-packages (from anndata>=0.7.5->scvi-tools) (5.5.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.8/dist-packages (from anndata>=0.7.5->scvi-tools) (23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from docrep>=0.3.2->scvi-tools) (1.15.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.8/dist-packages (from jax>=0.3->scvi-tools) (3.3.0)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.8/dist-packages (from ml-collections>=0.1.1->scvi-tools) (0.5.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from ml-collections>=0.1.1->scvi-tools) (6.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.8/dist-packages (from ml-collections>=0.1.1->scvi-tools) (1.4.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.8/dist-packages (from openpyxl>=3.0->scvi-tools) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0->scvi-tools) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0->scvi-tools) (2.8.2)
# Requirement already satisfied: pyro-api>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from pyro-ppl>=1.6.0->scvi-tools) (0.1.2)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (0.6.0.post0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (2023.1.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (4.5.0)
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in /usr/local/lib/python3.8/dist-packages (from rich>=12.0.0->scvi-tools) (2.14.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.1.0 in /usr/local/lib/python3.8/dist-packages (from rich>=12.0.0->scvi-tools) (2.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.2->scvi-tools) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.2->scvi-tools) (1.2.0)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.8/dist-packages (from chex->scvi-tools) (0.1.8)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from chex->scvi-tools) (0.12.0)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.8/dist-packages (from flax->scvi-tools) (0.1.32)
# Requirement already satisfied: orbax in /usr/local/lib/python3.8/dist-packages (from flax->scvi-tools) (0.1.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from flax->scvi-tools) (3.7.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.8/dist-packages (from flax->scvi-tools) (1.0.4)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.8/dist-packages (from numpyro->scvi-tools) (0.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (2.25.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (3.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.8/dist-packages (from markdown-it-py<3.0.0,>=2.1.0->rich>=12.0.0->scvi-tools) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax->scvi-tools) (1.0.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax->scvi-tools) (5.10.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax->scvi-tools) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax->scvi-tools) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax->scvi-tools) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax->scvi-tools) (7.1.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax->scvi-tools) (3.0.9)
# Requirement already satisfied: cached_property in /usr/local/lib/python3.8/dist-packages (from orbax->flax->scvi-tools) (1.5.2)
# Requirement already satisfied: etils in /usr/local/lib/python3.8/dist-packages (from orbax->flax->scvi-tools) (1.0.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (22.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (4.0.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (3.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (1.3.3)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib->flax->scvi-tools) (3.13.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (4.0.0)

# %%
#adata
# Out:
# AnnData object with n_obs × n_vars = 14923 × 2000
#     obs: 'n_genes', 'n_counts', 'orig_ident', 'stim', 'cluster', 'Donor', 'batch'
#     var: 'gene.mean-1', 'gene.dispersion-1', 'gene.dispersion.scaled-1', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'log1p', 'hvg'
#     layers: 'counts'

# %%
import scvi

# %%
adata.layers["counts"] = adata.X.copy()
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata

sc.pp.highly_variable_genes(adata, flavor = 'seurat_v3', n_top_genes=2000,
                            layer = "counts", batch_key="batch", subset = True)
# Out:
# WARNING: adata.X seems to be already log-transformed.
# /usr/local/lib/python3.8/dist-packages/scanpy/preprocessing/_highly_variable_genes.py:62: UserWarning: `flavor='seurat_v3'` expects raw count data, but non-integers were found.
#   warnings.warn(

# %%
# !pip install scvi-tools
# !pip install scikit-misc
# !pip install scanpy
# !pip install leidenalg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scvi-tools
#   Downloading scvi_tools-0.20.1-py3-none-any.whl (330 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.2/330.2 KB 23.8 MB/s eta 0:00:00
# Collecting numpyro
#   Downloading numpyro-0.11.0-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.2/300.2 KB 33.9 MB/s eta 0:00:00
# Requirement already satisfied: openpyxl>=3.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (3.0.10)
# Collecting mudata>=0.1.2
#   Downloading mudata-0.2.1-py3-none-any.whl (23 kB)
# Collecting ml-collections>=0.1.1
#   Downloading ml_collections-0.1.1.tar.gz (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 KB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting docrep>=0.3.2
#   Downloading docrep-0.3.2.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pytorch-lightning<1.10.0,>=1.9.0
#   Downloading pytorch_lightning-1.9.2-py3-none-any.whl (826 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 826.2/826.2 KB 51.9 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (3.1.0)
# Collecting rich>=12.0.0
#   Downloading rich-13.3.1-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.0/239.0 KB 26.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.21.2 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (1.0.2)
# Requirement already satisfied: tqdm>=4.56.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (4.64.1)
# Collecting chex
#   Downloading chex-0.1.6-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 KB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (1.3.5)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (1.21.6)
# Collecting optax
#   Downloading optax-0.1.4-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.9/154.9 KB 19.2 MB/s eta 0:00:00
# Collecting jax>=0.4.4
#   Downloading jax-0.4.4.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 54.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting flax
#   Downloading flax-0.6.4-py3-none-any.whl (204 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.3/204.3 KB 20.4 MB/s eta 0:00:00
# Collecting jaxlib>=0.4.3
#   Downloading jaxlib-0.4.4-cp38-cp38-manylinux2014_x86_64.whl (72.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.6/72.6 MB 13.6 MB/s eta 0:00:00
# Collecting torchmetrics>=0.11.0
#   Downloading torchmetrics-0.11.1-py3-none-any.whl (517 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.2/517.2 KB 50.5 MB/s eta 0:00:00
# Collecting pyro-ppl>=1.6.0
#   Downloading pyro_ppl-1.8.4-py3-none-any.whl (730 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 730.7/730.7 KB 62.9 MB/s eta 0:00:00
# Requirement already satisfied: anndata>=0.7.5 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (0.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (1.7.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.8/dist-packages (from scvi-tools) (1.13.1+cu116)
# Requirement already satisfied: natsort in /usr/local/lib/python3.8/dist-packages (from anndata>=0.7.5->scvi-tools) (5.5.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.8/dist-packages (from anndata>=0.7.5->scvi-tools) (23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from docrep>=0.3.2->scvi-tools) (1.15.0)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.8/dist-packages (from jax>=0.4.4->scvi-tools) (3.3.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.8/dist-packages (from ml-collections>=0.1.1->scvi-tools) (1.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from ml-collections>=0.1.1->scvi-tools) (6.0)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.8/dist-packages (from ml-collections>=0.1.1->scvi-tools) (0.5.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.8/dist-packages (from openpyxl>=3.0->scvi-tools) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0->scvi-tools) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0->scvi-tools) (2.8.2)
# Collecting pyro-api>=0.1.1
#   Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (2023.1.0)
# Collecting lightning-utilities>=0.6.0.post0
#   Downloading lightning_utilities-0.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (4.5.0)
# Collecting markdown-it-py<3.0.0,>=2.1.0
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 11.2 MB/s eta 0:00:00
# Collecting pygments<3.0.0,>=2.14.0
#   Downloading Pygments-2.14.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 76.6 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.2->scvi-tools) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.2->scvi-tools) (1.2.0)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.8/dist-packages (from chex->scvi-tools) (0.1.8)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from chex->scvi-tools) (0.12.0)
# Collecting orbax
#   Downloading orbax-0.1.2-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 KB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: msgpack in /usr/local/lib/python3.8/dist-packages (from flax->scvi-tools) (1.0.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from flax->scvi-tools) (3.7.0)
# Collecting tensorstore
#   Downloading tensorstore-0.1.32-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 109.7 MB/s eta 0:00:00
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.8/dist-packages (from numpyro->scvi-tools) (0.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (3.8.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (2.25.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax->scvi-tools) (5.10.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax->scvi-tools) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax->scvi-tools) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax->scvi-tools) (7.1.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax->scvi-tools) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax->scvi-tools) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax->scvi-tools) (1.0.7)
# Collecting cached_property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: etils in /usr/local/lib/python3.8/dist-packages (from orbax->flax->scvi-tools) (1.0.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (3.0.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (1.8.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (6.0.4)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib->flax->scvi-tools) (3.13.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning<1.10.0,>=1.9.0->scvi-tools) (1.24.3)
# Building wheels for collected packages: docrep, jax, ml-collections
#   Building wheel for docrep (setup.py) ... done
#   Created wheel for docrep: filename=docrep-0.3.2-py3-none-any.whl size=19896 sha256=9db5b162a7fbfb93c3aa5d02885ccc9e2b5f6273c261981972296a540a6e7944
#   Stored in directory: /root/.cache/pip/wheels/48/f0/c9/3928c369e4e0aae8c3daa3c36e5ddf982aed49d3196addc1f0
#   Building wheel for jax (setup.py) ... done
#   Created wheel for jax: filename=jax-0.4.4-py3-none-any.whl size=1403844 sha256=49aab447f1b2b07f6016e71cac6580b85ce4910165fdcf21214408cd1d5ac0d3
#   Stored in directory: /root/.cache/pip/wheels/5e/cd/9b/750eb95db5b18b776ae59f55ae22b91a01e3703f3fb07eaa13
#   Building wheel for ml-collections (setup.py) ... done
#   Created wheel for ml-collections: filename=ml_collections-0.1.1-py3-none-any.whl size=94524 sha256=26733d2b10534b4481faf74df8abe1ac88de095697e775b73f6c91fea8c93f5f
#   Stored in directory: /root/.cache/pip/wheels/6d/9f/a9/9e8309035a5bf09ed9086bbca8c9b74cb6413d3eb203e2bc8c
# Successfully built docrep jax ml-collections
# Installing collected packages: pyro-api, cached_property, tensorstore, pygments, ml-collections, mdurl, lightning-utilities, docrep, torchmetrics, pyro-ppl, markdown-it-py, jaxlib, jax, rich, numpyro, chex, pytorch-lightning, optax, mudata, orbax, flax, scvi-tools
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.3.25+cuda11.cudnn805
#     Uninstalling jaxlib-0.3.25+cuda11.cudnn805:
#       Successfully uninstalled jaxlib-0.3.25+cuda11.cudnn805
#   Attempting uninstall: jax
#     Found existing installation: jax 0.3.25
#     Uninstalling jax-0.3.25:
#       Successfully uninstalled jax-0.3.25
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# Successfully installed cached_property-1.5.2 chex-0.1.6 docrep-0.3.2 flax-0.6.4 jax-0.4.4 jaxlib-0.4.4 lightning-utilities-0.7.0 markdown-it-py-2.1.0 mdurl-0.1.2 ml-collections-0.1.1 mudata-0.2.1 numpyro-0.11.0 optax-0.1.4 orbax-0.1.2 pygments-2.14.0 pyro-api-0.1.2 pyro-ppl-1.8.4 pytorch-lightning-1.9.2 rich-13.3.1 scvi-tools-0.20.1 tensorstore-0.1.32 torchmetrics-0.11.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-misc in /usr/local/lib/python3.8/dist-packages (0.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from scikit-misc) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scanpy in /usr/local/lib/python3.8/dist-packages (1.9.2)
# Requirement already satisfied: anndata>=0.7.4 in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.8.0)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.3.5)
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.8/dist-packages (from scanpy) (3.1.0)
# Requirement already satisfied: patsy in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.5.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.8/dist-packages (from scanpy) (5.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from scanpy) (23.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.21.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.2.0)
# Requirement already satisfied: session-info in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.0.0)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.7.3)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.8/dist-packages (from scanpy) (3.7.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.11.2)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.12.2)
# Requirement already satisfied: umap-learn>=0.3.10 in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from scanpy) (4.64.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from scanpy) (1.0.2)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.8/dist-packages (from scanpy) (0.56.4)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.8/dist-packages (from scanpy) (3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (7.1.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (5.10.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy) (1.0.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy) (0.39.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy) (6.0.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0->scanpy) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->scanpy) (3.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy->scanpy) (1.15.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.8/dist-packages (from umap-learn>=0.3.10->scanpy) (0.5.8)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.8/dist-packages (from session-info->scanpy) (0.8.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.4->scanpy) (3.13.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting leidenalg
#   Downloading leidenalg-0.9.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 55.1 MB/s eta 0:00:00
# Collecting igraph<0.11,>=0.10.0
#   Downloading igraph-0.10.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 92.0 MB/s eta 0:00:00
# Collecting texttable>=1.6.2
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph, leidenalg
# Successfully installed igraph-0.10.4 leidenalg-0.9.1 texttable-1.6.7

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 14923 × 2000
#     obs: 'n_genes', 'n_counts', 'orig_ident', 'stim', 'cluster', 'Donor', 'batch'
#     var: 'gene.mean-1', 'gene.dispersion-1', 'gene.dispersion.scaled-1', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'log1p', 'hvg'
#     layers: 'counts'

# %%
# !pip install --quiet scvi-colab
# !pip install --quiet scib-metrics
from scvi_colab import install

install()
# Out:
# INFO     scvi-colab: Installing scvi-tools.
# INFO     scvi-colab: Install successful. Testing import.

# %%
scvi.model.SCVI.setup_anndata(adata, layer="counts", batch_key="batch")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-6261fb51db10> in <module>
# ----> 1 scvi.model.SCVI.setup_anndata(adata, layer="counts", batch_key="batch")
#
# AttributeError: module 'scvi' has no attribute 'model'

# %%
adata.layers["counts"] = adata.X.copy()
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
adata.raw = adata

sc.pp.highly_variable_genes(adata, flavor = 'seurat_v3', n_top_genes=2000,
                            layer = "counts", batch_key="batch", subset = True)
# Out:
# WARNING: adata.X seems to be already log-transformed.
# /usr/local/lib/python3.8/dist-packages/scanpy/preprocessing/_highly_variable_genes.py:62: UserWarning: `flavor='seurat_v3'` expects raw count data, but non-integers were found.
#   warnings.warn(

# %%
scvi.model.SCVI.setup_anndata(adata, layer = 'counts', batch_key='batch')
vae = scvi.model.SCVI(adata)
vae.train()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-c08c83957a18> in <module>
# ----> 1 scvi.model.SCVI.setup_anndata(adata, layer = 'counts', batch_key='batch')
#       2 vae = scvi.model.SCVI(adata)
#       3 vae.train()
#
# AttributeError: module 'scvi' has no attribute 'model'

# %%
model = scvi.model.SCVI(adata)

# %%
scvi.model.SCVI.setup_anndata(adata, layer = 'counts', batch_key='batch')
vae = scvi.model.SCVI(adata)
vae.train()
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 1/400:   0%|          | 0/400 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/scvi/distributions/_negative_binomial.py:481: UserWarning: The value argument must be within the support of the distribution
#   warnings.warn(
# Epoch 400/400: 100%|██████████| 400/400 [09:55<00:00,  1.34s/it, loss=564, v_num=1]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=400` reached.
# Epoch 400/400: 100%|██████████| 400/400 [09:55<00:00,  1.49s/it, loss=564, v_num=1]

# %%
adata.obs['cluster'] = adata.obs['cluster'].cat.add_categories('Unknown')
adata.obs = adata.obs.fillna(value = {'cluster': 'Unknown'})
adata.obs
# Out:
#                          n_genes  n_counts orig_ident  stim  cluster  \
# AAACCCAAGGAGAGTA-1-0         NaN       NaN        NaN   NaN  Unknown
# AAACGCTTCAGCCCAG-1-0         NaN       NaN        NaN   NaN  Unknown
# AAAGAACAGACGACTG-1-0         NaN       NaN        NaN   NaN  Unknown
# AAAGAACCAATGGCAG-1-0         NaN       NaN        NaN   NaN  Unknown
# AAAGAACGTCTGCAAT-1-0         NaN       NaN        NaN   NaN  Unknown
# ...                          ...       ...        ...   ...      ...
# STIM_TCCCGAACTTCGTT.1-1    702.0    4222.0       STIM  STIM    Eryth
# STIM_TCGGACCTATCAGC.1-1    502.0    2050.0       STIM  STIM    Eryth
# STIM_TGACGCCTCTTGTT.1-1    899.0    7168.0       STIM  STIM    Eryth
# STIM_TGGTCAGACAAGCT.1-1    550.0    4225.0       STIM  STIM    Eryth
# STIM_TGTGAGTGTCTTAC.1-1    607.0    2804.0       STIM  STIM    Eryth
#
#                             Donor batch  _scvi_batch  _scvi_labels
# AAACCCAAGGAGAGTA-1-0          NaN     0            0             0
# AAACGCTTCAGCCCAG-1-0          NaN     0            0             0
# AAAGAACAGACGACTG-1-0          NaN     0            0             0
# AAAGAACCAATGGCAG-1-0          NaN     0            0             0
# AAAGAACGTCTGCAAT-1-0          NaN     0            0             0
# ...                           ...   ...          ...           ...
# STIM_TCCCGAACTTCGTT.1-1  SNG-1015     1            1             0
# STIM_TCGGACCTATCAGC.1-1   SNG-101     1            1             0
# STIM_TGACGCCTCTTGTT.1-1  SNG-1015     1            1             0
# STIM_TGGTCAGACAAGCT.1-1  SNG-1039     1            1             0
# STIM_TGTGAGTGTCTTAC.1-1  SNG-1256     1            1             0
#
# [14923 rows x 9 columns]

# %%
#adata.obs.tail()
# Out:
#                          n_genes  n_counts orig_ident  stim cluster     Donor  \
# STIM_TCCCGAACTTCGTT.1-1    702.0    4222.0       STIM  STIM   Eryth  SNG-1015
# STIM_TCGGACCTATCAGC.1-1    502.0    2050.0       STIM  STIM   Eryth   SNG-101
# STIM_TGACGCCTCTTGTT.1-1    899.0    7168.0       STIM  STIM   Eryth  SNG-1015
# STIM_TGGTCAGACAAGCT.1-1    550.0    4225.0       STIM  STIM   Eryth  SNG-1039
# STIM_TGTGAGTGTCTTAC.1-1    607.0    2804.0       STIM  STIM   Eryth  SNG-1256
#
#                         batch  _scvi_batch  _scvi_labels
# STIM_TCCCGAACTTCGTT.1-1     1            1             0
# STIM_TCGGACCTATCAGC.1-1     1            1             0
# STIM_TGACGCCTCTTGTT.1-1     1            1             0
# STIM_TGGTCAGACAAGCT.1-1     1            1             0
# STIM_TGTGAGTGTCTTAC.1-1     1            1             0

# %%
lvae = scvi.model.SCANVI.from_scvi_model(vae, adata = adata, unlabeled_category = 'Unknown',
                                        labels_key = 'cluster')

lvae.train(max_epochs=20, n_samples_per_label=100)
# Out:
# INFO     Training for 20 epochs.
# /usr/local/lib/python3.8/dist-packages/scvi/data/fields/_layer_field.py:91: UserWarning: adata.layers[counts] does not contain unnormalized count data. Are you sure this is what you want?
#   warnings.warn(
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 1/20:   0%|          | 0/20 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/scvi/distributions/_negative_binomial.py:481: UserWarning: The value argument must be within the support of the distribution
#   warnings.warn(
# Epoch 20/20: 100%|██████████| 20/20 [00:56<00:00,  2.64s/it, loss=634, v_num=1]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=20` reached.
# Epoch 20/20: 100%|██████████| 20/20 [00:56<00:00,  2.82s/it, loss=634, v_num=1]

# %%
adata.obs['predicted'] = lvae.predict(adata)
adata.obs
# Out:
#                          n_genes  n_counts orig_ident  stim  cluster  \
# AAACCCAAGGAGAGTA-1-0         NaN       NaN        NaN   NaN  Unknown
# AAACGCTTCAGCCCAG-1-0         NaN       NaN        NaN   NaN  Unknown
# AAAGAACAGACGACTG-1-0         NaN       NaN        NaN   NaN  Unknown
# AAAGAACCAATGGCAG-1-0         NaN       NaN        NaN   NaN  Unknown
# AAAGAACGTCTGCAAT-1-0         NaN       NaN        NaN   NaN  Unknown
# ...                          ...       ...        ...   ...      ...
# STIM_TCCCGAACTTCGTT.1-1    702.0    4222.0       STIM  STIM    Eryth
# STIM_TCGGACCTATCAGC.1-1    502.0    2050.0       STIM  STIM    Eryth
# STIM_TGACGCCTCTTGTT.1-1    899.0    7168.0       STIM  STIM    Eryth
# STIM_TGGTCAGACAAGCT.1-1    550.0    4225.0       STIM  STIM    Eryth
# STIM_TGTGAGTGTCTTAC.1-1    607.0    2804.0       STIM  STIM    Eryth
#
#                             Donor batch  _scvi_batch  _scvi_labels  \
# AAACCCAAGGAGAGTA-1-0          NaN     0            0            13
# AAACGCTTCAGCCCAG-1-0          NaN     0            0            13
# AAAGAACAGACGACTG-1-0          NaN     0            0            13
# AAAGAACCAATGGCAG-1-0          NaN     0            0            13
# AAAGAACGTCTGCAAT-1-0          NaN     0            0            13
# ...                           ...   ...          ...           ...
# STIM_TCCCGAACTTCGTT.1-1  SNG-1015     1            1             8
# STIM_TCGGACCTATCAGC.1-1   SNG-101     1            1             8
# STIM_TGACGCCTCTTGTT.1-1  SNG-1015     1            1             8
# STIM_TGGTCAGACAAGCT.1-1  SNG-1039     1            1             8
# STIM_TGTGAGTGTCTTAC.1-1  SNG-1256     1            1             8
#
#                             predicted
# AAACCCAAGGAGAGTA-1-0        CD14 Mono
# AAACGCTTCAGCCCAG-1-0                B
# AAAGAACAGACGACTG-1-0            CD8 T
# AAAGAACCAATGGCAG-1-0            CD8 T
# AAAGAACGTCTGCAAT-1-0     CD4 Memory T
# ...                               ...
# STIM_TCCCGAACTTCGTT.1-1     CD14 Mono
# STIM_TCGGACCTATCAGC.1-1            Mk
# STIM_TGACGCCTCTTGTT.1-1     CD16 Mono
# STIM_TGGTCAGACAAGCT.1-1            Mk
# STIM_TGTGAGTGTCTTAC.1-1   B activated
#
# [14923 rows x 10 columns]

# %%
adata.obs['bc2'] = adata.obs.index.map(lambda x: x[:-2])

cell_mapper = dict(zip(adata.obs.bc2, adata.obs.predicted))

# %%
cell_mapper
# Out:
# {'AAACCCAAGGAGAGTA-1': 'CD14 Mono',
#  'AAACGCTTCAGCCCAG-1': 'B',
#  'AAAGAACAGACGACTG-1': 'CD8 T',
#  'AAAGAACCAATGGCAG-1': 'CD8 T',
#  'AAAGAACGTCTGCAAT-1': 'CD4 Memory T',
#  'AAAGGATAGTAGACAT-1': 'B',
#  'AAAGGATCACCGGCTA-1': 'B',
#  'AAAGGATTCAGCTTGA-1': 'CD14 Mono',
#  'AAAGGATTCCGTTTCG-1': 'CD14 Mono',
#  'AAAGGGCTCATGCCCT-1': 'CD4 Naive T',
#  'AAAGGGCTCCGTAGGC-1': 'CD8 T',
#  'AAAGGTACAACTGCTA-1': 'CD16 Mono',
#  'AAAGTCCAGCGGGTTA-1': 'CD4 Naive T',
#  'AAAGTCCCACCAGCCA-1': 'B',
#  'AAAGTGATCGTACACA-1': 'NK',
#  'AAATGGAAGCCGCTTG-1': 'CD14 Mono',
#  'AAATGGACAATGCTCA-1': 'DC',
#  'AAATGGAGTACCGCGT-1': 'CD8 T',
#  'AAATGGATCCTATTTG-1': 'B',
#  'AACAAAGGTGATGAAT-1': 'CD4 Memory T',
#  'AACAACCAGTAGTCCT-1': 'CD14 Mono',
#  'AACAACCCACGCTATA-1': 'CD8 T',
#  'AACAAGAGTTATAGAG-1': 'CD16 Mono',
#  'AACAGGGGTGGGAGAG-1': 'CD8 T',
#  'AACCAACAGCTTGTTG-1': 'T activated',
#  'AACCCAACAACTGATC-1': 'CD8 T',
#  'AACCCAAGTGGGCTTC-1': 'B',
#  'AACCCAATCTTACCGC-1': 'NK',
#  'AACCTGACATCCTATT-1': 'CD14 Mono',
#  'AACCTTTGTTTCGGCG-1': 'NK',
#  'AACGAAAAGGTTGGTG-1': 'Mk',
#  'AACGAAACAGCGTTTA-1': 'CD14 Mono',
#  'AACGAAATCCATTTAC-1': 'CD4 Memory T',
#  'AACGGGAGTCGCTCGA-1': 'CD14 Mono',
#  'AACGTCAAGACGCCCT-1': 'CD14 Mono',
#  'AAGAACAAGACCATTC-1': 'CD8 T',
#  'AAGAACAAGCCTCAGC-1': 'CD16 Mono',
#  'AAGAACATCTTGCAAG-1': 'CD4 Naive T',
#  'AAGACAACACTTCAGA-1': 'CD14 Mono',
#  'AAGACAACAGATCACT-1': 'DC',
#  'AAGACAATCCGCGAGT-1': 'CD4 Naive T',
#  'AAGCATCAGGTCCGAA-1': 'CD4 Naive T',
#  'AAGCATCCAGTCTTCC-1': 'DC',
#  'AAGCGTTCACTGATTG-1': 'DC',
#  'AAGCGTTTCGCTATTT-1': 'B activated',
#  'AAGGTAAAGGAAGTAG-1': 'CD8 T',
#  'AAGGTAAAGGCCACCT-1': 'CD4 Memory T',
#  'AAGGTAAGTCCTTAAG-1': 'CD4 Naive T',
#  'AAGTACCAGCGCCTTG-1': 'CD4 Naive T',
#  'AAGTACCAGCTCCATA-1': 'CD4 Naive T',
#  'AAGTACCCAAAGAACT-1': 'CD4 Naive T',
#  'AAGTGAACATCAGCAT-1': 'CD8 T',
#  'AAGTGAATCGGAAGGT-1': 'DC',
#  'AAGTTCGAGGATACAT-1': 'CD4 Naive T',
#  'AAGTTCGGTCAACACT-1': 'CD14 Mono',
#  'AATCGACGTGAGACGT-1': 'CD14 Mono',
#  'AATGACCGTGTCATCA-1': 'NK',
#  'AATGGAACACTCATAG-1': 'B',
#  'AATGGAATCTGATGGT-1': 'CD14 Mono',
#  'AATTCCTTCCATTGGA-1': 'CD16 Mono',
#  'ACAAAGAAGCCTCAAT-1': 'CD14 Mono',
#  'ACAAAGAGTTCCATTT-1': 'CD4 Memory T',
#  'ACAACCATCTATCCAT-1': 'CD4 Naive T',
#  'ACAACCATCTGCCCTA-1': 'T activated',
#  'ACAAGCTGTAGGTCAG-1': 'CD8 T',
#  'ACACCAAAGAGTCAGC-1': 'CD4 Naive T',
#  'ACACGCGGTGTTGCCG-1': 'CD16 Mono',
#  'ACACGCGTCACCTCGT-1': 'NK',
#  'ACACGCGTCGCCGTGA-1': 'CD14 Mono',
#  'ACACTGATCACTGATG-1': 'CD14 Mono',
#  'ACACTGATCTTTCCGG-1': 'CD8 T',
#  'ACAGAAAAGTATTAGG-1': 'CD14 Mono',
#  'ACAGAAACACCAGCGT-1': 'CD14 Mono',
#  'ACAGCCGTCGCTGTTC-1': 'B',
#  'ACATCCCCACAAATGA-1': 'CD8 T',
#  'ACATCCCGTAAGATTG-1': 'CD14 Mono',
#  'ACATCGATCTAAGAAG-1': 'NK',
#  'ACATCGATCTGAGAGG-1': 'CD8 T',
#  'ACATCGATCTTGGGCG-1': 'CD14 Mono',
#  'ACATGCAGTTGCTTGA-1': 'CD14 Mono',
#  'ACATTTCGTGCCGAAA-1': 'CD4 Naive T',
#  'ACATTTCGTTTCTTAC-1': 'B',
#  'ACCACAAAGGCCTTGC-1': 'CD14 Mono',
#  'ACCACAAGTCTGTGGC-1': 'B',
#  'ACCATTTCATTGGGAG-1': 'CD8 T',
#  'ACCCAAAGTTGGGAAC-1': 'DC',
#  'ACCCTTGGTATCGTAC-1': 'CD8 T',
#  'ACCCTTGTCATTTCGT-1': 'CD8 T',
#  'ACCTACCCAACGGTAG-1': 'CD8 T',
#  'ACCTGAACATGAGAAT-1': 'CD4 Naive T',
#  'ACCTGTCTCAAGTCTG-1': 'CD4 Naive T',
#  'ACCTGTCTCTCAACGA-1': 'CD16 Mono',
#  'ACGATCAGTCGTTCAA-1': 'CD8 T',
#  'ACGATCATCCACGGAC-1': 'CD8 T',
#  'ACGATCATCCGTTGGG-1': 'CD4 Naive T',
#  'ACGCACGAGAGAGTGA-1': 'NK',
#  'ACGGTCGTCACTACGA-1': 'CD4 Naive T',
#  'ACGGTTAAGTGCTCAT-1': 'B',
#  'ACGTAACAGGTGCTTT-1': 'CD4 Naive T',
#  'ACGTAACTCATATGGC-1': 'B',
#  'ACGTAACTCTTCGATT-1': 'CD14 Mono',
#  'ACGTACAAGCTGTTCA-1': 'CD8 T',
#  'ACGTACACAAAGCTCT-1': 'CD16 Mono',
#  'ACGTACACAGACGATG-1': 'NK',
#  'ACGTAGTCACGCCACA-1': 'B',
#  'ACGTAGTCATTAGGAA-1': 'CD8 T',
#  'ACGTTCCGTGGGTCAA-1': 'CD14 Mono',
#  'ACTATCTGTGTGTACT-1': 'NK',
#  'ACTATGGAGAAATCCA-1': 'DC',
#  'ACTCCCAAGGTTGGTG-1': 'NK',
#  'ACTCCCATCGTCCTCA-1': 'CD4 Naive T',
#  'ACTGATGAGCAGCGAT-1': 'B',
#  'ACTGATGCACCAGCCA-1': 'B',
#  'ACTGTGACAACTCGAT-1': 'CD4 Naive T',
#  'ACTTATCTCTAAGGAA-1': 'DC',
#  'ACTTCGCAGAACCGCA-1': 'CD4 Naive T',
#  'ACTTCGCGTACTCCGG-1': 'B',
#  'ACTTTCAAGTATGACA-1': 'CD8 T',
#  'ACTTTCAGTACGCGTC-1': 'CD4 Memory T',
#  'AGAAGCGGTCTAGATC-1': 'CD4 Memory T',
#  'AGAAGCGTCTGCGTCT-1': 'CD4 Memory T',
#  'AGACAAAGTAGCTTGT-1': 'CD14 Mono',
#  'AGACACTCAAGTCGTT-1': 'CD4 Memory T',
#  'AGACCATCATTACTCT-1': 'CD4 Naive T',
#  'AGACTCATCAACGCTA-1': 'CD4 Naive T',
#  'AGACTCATCAGAGCGA-1': 'CD14 Mono',
#  'AGAGAATAGAGGGTCT-1': 'CD8 T',
#  'AGAGAATCACCCAACG-1': 'CD4 Naive T',
#  'AGAGAGCAGTTGTCGT-1': 'B',
#  'AGAGCAGGTCATAAAG-1': 'CD14 Mono',
#  'AGAGCAGGTTGAGTCT-1': 'CD4 Naive T',
#  'AGAGCAGTCGCGCTGA-1': 'CD8 T',
#  'AGAGCCCGTCACTCGG-1': 'CD4 Naive T',
#  'AGATAGAGTGACACGA-1': 'CD14 Mono',
#  'AGATCGTCAGGACTTT-1': 'CD8 T',
#  'AGATGAACAGGCACAA-1': 'CD8 T',
#  'AGATGCTGTACGGTTT-1': 'CD14 Mono',
#  'AGATGCTGTGTGGTCC-1': 'CD4 Naive T',
#  'AGCATCAGTCGGTGTC-1': 'CD14 Mono',
#  'AGCATCAGTGGTCCGT-1': 'CD4 Naive T',
#  'AGCCAATAGTCCCTAA-1': 'T activated',
#  'AGCCACGCAGGTTCGC-1': 'CD4 Naive T',
#  'AGCCACGGTTCCGCGA-1': 'CD14 Mono',
#  'AGCCACGTCCGAGAAG-1': 'CD8 T',
#  'AGCCAGCGTAATGCGG-1': 'CD4 Naive T',
#  'AGCCAGCGTAGTTAGA-1': 'pDC',
#  'AGCGTATTCAGTGGGA-1': 'B',
#  'AGCGTCGCATTGACCA-1': 'CD4 Naive T',
#  'AGCTACACAGTCGGAA-1': 'CD8 T',
#  'AGCTACAGTCGTTTCC-1': 'CD8 T',
#  'AGGAAATTCACCATGA-1': 'CD16 Mono',
#  'AGGAATACAAACTCGT-1': 'CD4 Naive T',
#  'AGGAATATCATTACGG-1': 'CD4 Naive T',
#  'AGGACGAAGACCTTTG-1': 'NK',
#  'AGGACGAAGATTAGTG-1': 'CD4 Naive T',
#  'AGGACGATCACTGATG-1': 'CD4 Naive T',
#  'AGGACGATCCAGTACA-1': 'CD8 T',
#  'AGGACTTTCCTACCAC-1': 'CD8 T',
#  'AGGATAAAGAACAAGG-1': 'CD4 Naive T',
#  'AGGCCACAGGGCCAAT-1': 'CD4 Naive T',
#  'AGGCTGCAGGGCTTCC-1': 'B',
#  'AGGCTGCGTGTGTGTT-1': 'B',
#  'AGGGAGTGTGTCGCTG-1': 'CD4 Naive T',
#  'AGGGCTCCAATACGCT-1': 'CD14 Mono',
#  'AGGGTCCCAGGACATG-1': 'CD14 Mono',
#  'AGGGTCCCAGTAGTTC-1': 'CD8 T',
#  'AGGGTTTCAGCGTGCT-1': 'CD14 Mono',
#  'AGGTAGGAGGAAGTAG-1': 'B',
#  'AGGTAGGCAAAGCGTG-1': 'CD14 Mono',
#  'AGGTCATTCAAGTCGT-1': 'CD14 Mono',
#  'AGGTGTTCATTAAGCC-1': 'CD14 Mono',
#  'AGGTGTTGTCGATTAC-1': 'CD4 Memory T',
#  'AGGTGTTTCAATGCAC-1': 'CD4 Naive T',
#  'AGGTTACAGGTGCGAT-1': 'CD4 Naive T',
#  'AGGTTACGTCTGATAC-1': 'CD16 Mono',
#  'AGTAACCCAAGCTCTA-1': 'CD14 Mono',
#  'AGTAACCTCGTTGTAG-1': 'CD4 Naive T',
#  'AGTACCAGTGGGTCAA-1': 'CD14 Mono',
#  'AGTACCATCAGCTTGA-1': 'NK',
#  'AGTAGCTAGGAGTACC-1': 'B',
#  'AGTAGCTCAGGCACTC-1': 'CD14 Mono',
#  'AGTAGCTGTTAGAAAC-1': 'CD14 Mono',
#  'AGTAGTCGTATGACAA-1': 'CD4 Memory T',
#  'AGTCAACAGTCATGCT-1': 'CD14 Mono',
#  'AGTCAACGTACACGCC-1': 'pDC',
#  'AGTCTCCCAACCGTGC-1': 'B',
#  'AGTCTCCGTGAGTCAG-1': 'CD8 T',
#  'AGTGCCGCATCTGGGC-1': 'NK',
#  'AGTTAGCAGTCAGGGT-1': 'CD8 T',
#  'AGTTAGCGTACCATAC-1': 'B',
#  'AGTTAGCGTTCATCGA-1': 'CD8 T',
#  'AGTTCCCCAAACAGGC-1': 'CD8 T',
#  'AGTTCCCGTTACACTG-1': 'CD4 Naive T',
#  'AGTTCGAGTATGCGTT-1': 'B',
#  'ATACCGACACACGGTC-1': 'T activated',
#  'ATACTTCGTACGACTT-1': 'CD14 Mono',
#  'ATACTTCGTTCGGTAT-1': 'CD4 Naive T',
#  'ATACTTCTCAGCTGAT-1': 'CD4 Memory T',
#  'ATACTTCTCGCCGTGA-1': 'B',
#  'ATAGACCTCCGCTTAC-1': 'NK',
#  'ATAGGCTGTGTTACAC-1': 'CD14 Mono',
#  'ATATCCTGTATGAGCG-1': 'B',
#  'ATCACAGAGACGTCCC-1': 'CD14 Mono',
#  'ATCACAGCATGACGTT-1': 'CD14 Mono',
#  'ATCACGATCCGCAACG-1': 'CD8 T',
#  'ATCACTTGTGGCTGCT-1': 'CD14 Mono',
#  'ATCCACCCAGCAGTGA-1': 'NK',
#  'ATCCACCCATGTCTAG-1': 'NK',
#  'ATCCACCGTTTGTTGG-1': 'CD14 Mono',
#  'ATCCATTAGACGCAGT-1': 'B',
#  'ATCCCTGCAATTTCTC-1': 'CD8 T',
#  'ATCCGTCCAACTCCCT-1': 'B',
#  'ATCCTATGTCTGTGCG-1': 'B',
#  'ATCGATGCAACGGCTC-1': 'B',
#  'ATCGATGGTCAATCTG-1': 'NK',
#  'ATCGGATAGGAAAGGT-1': 'CD8 T',
#  'ATCGTAGCATCGGAGA-1': 'CD14 Mono',
#  'ATCGTCCAGCCTGAAG-1': 'CD16 Mono',
#  'ATCGTCCGTATGAGGC-1': 'CD14 Mono',
#  'ATCGTCCTCGGAGCAA-1': 'CD16 Mono',
#  'ATCGTGAAGCAGATAT-1': 'CD14 Mono',
#  'ATCTCTACAAGAAACT-1': 'CD14 Mono',
#  'ATCTTCAAGAAGAGCA-1': 'CD14 Mono',
#  'ATCTTCACATACTGAC-1': 'CD14 Mono',
#  'ATCTTCAGTCTCTCCA-1': 'CD14 Mono',
#  'ATCTTCATCTCATAGG-1': 'CD8 T',
#  'ATGAAAGTCCTTATGT-1': 'CD4 Memory T',
#  'ATGACCAAGGCTAACG-1': 'DC',
#  'ATGACCACAATATCCG-1': 'CD4 Memory T',
#  'ATGAGTCTCCAGTTCC-1': 'B',
#  'ATGATCGGTCGAACAG-1': 'B',
#  'ATGCGATGTGCTCTTC-1': 'B',
#  'ATGCGATGTTGTAGCT-1': 'CD4 Memory T',
#  'ATGGATCGTAGATTGA-1': 'B',
#  'ATGGATCTCGACCTAA-1': 'CD4 Memory T',
#  'ATGGGAGAGACGTCCC-1': 'CD4 Naive T',
#  'ATGGGAGCACTCCGGA-1': 'CD16 Mono',
#  'ATGGGAGTCCACTGAA-1': 'CD14 Mono',
#  'ATGGTTGTCACGGAGA-1': 'CD14 Mono',
#  'ATGTCCCCAGGAATCG-1': 'B',
#  'ATGTCCCCATAGGTTC-1': 'B',
#  'ATGTCCCGTCCTACGG-1': 'CD14 Mono',
#  'ATTACTCCAGCTTTGA-1': 'T activated',
#  'ATTACTCGTTGCAACT-1': 'B',
#  'ATTCACTAGAAGGCTC-1': 'CD8 T',
#  'ATTCACTTCTCCGCAT-1': 'NK',
#  'ATTCAGGCAAGTATCC-1': 'CD14 Mono',
#  'ATTCAGGCATAGCTGT-1': 'CD14 Mono',
#  'ATTCAGGTCTTCGTGC-1': 'CD8 T',
#  'ATTCCCGAGTCACTCA-1': 'CD4 Naive T',
#  'ATTCCTACATGAGATA-1': 'CD14 Mono',
#  'ATTCGTTCAGTCTTCC-1': 'CD4 Memory T',
#  'ATTCGTTGTAACACCT-1': 'CD4 Naive T',
#  'ATTCGTTGTGTAGCAG-1': 'pDC',
#  'ATTCGTTGTGTTCAGT-1': 'CD4 Memory T',
#  'ATTCGTTGTTCTTGTT-1': 'CD14 Mono',
#  'ATTCTACTCTCGTGAA-1': 'CD4 Naive T',
#  'ATTCTTGGTACAATAG-1': 'CD8 T',
#  'ATTTCACAGTGCAAAT-1': 'CD16 Mono',
#  'ATTTCACGTGGATACG-1': 'CD14 Mono',
#  'ATTTCTGCAAGGTCTT-1': 'CD14 Mono',
#  'ATTTCTGGTATCCTCC-1': 'B',
#  'ATTTCTGTCGATGCAT-1': 'CD14 Mono',
#  'ATTTCTGTCGGCCAAC-1': 'CD4 Memory T',
#  'CAAAGAACACATATCG-1': 'CD4 Memory T',
#  'CAAAGAACAGCTGTTA-1': 'CD8 T',
#  'CAAAGAAGTTCTCCCA-1': 'CD14 Mono',
#  'CAACAACTCGATACTG-1': 'CD8 T',
#  'CAACAGTCATCCGTTC-1': 'CD4 Naive T',
#  'CAACAGTTCGAGCACC-1': 'CD4 Naive T',
#  'CAACCAAGTTAGAAAC-1': 'CD14 Mono',
#  'CAACCTCGTATCGGTT-1': 'CD4 Memory T',
#  'CAACGATAGACGGAAA-1': 'CD14 Mono',
#  'CAACGATAGCCTAGGA-1': 'CD14 Mono',
#  'CAACGATCAAAGCACG-1': 'CD4 Memory T',
#  'CAACGATTCAAGCCCG-1': 'CD14 Mono',
#  'CAAGACTAGTGGAAAG-1': 'CD8 T',
#  'CAAGACTTCAATCGGT-1': 'CD14 Mono',
#  'CAAGAGGTCTTCACGC-1': 'CD14 Mono',
#  'CAAGCTAGTGGCTGCT-1': 'DC',
#  'CAAGGGAAGAGTCGAC-1': 'CD4 Memory T',
#  'CAATCGAAGAGGATCC-1': 'CD4 Memory T',
#  'CAATCGATCCGTACGG-1': 'CD4 Memory T',
#  'CAATGACTCAAGCCCG-1': 'CD4 Naive T',
#  'CAATTTCAGATTGCGG-1': 'B',
#  'CACACAACAAGAAACT-1': 'CD4 Naive T',
#  'CACACAACACGAGGAT-1': 'CD14 Mono',
#  'CACAGATCACTCCGAG-1': 'CD16 Mono',
#  'CACAGATCATCATGAC-1': 'CD14 Mono',
#  'CACAGATGTTCCGTTC-1': 'CD16 Mono',
#  'CACAGGCCAACGATCT-1': 'CD14 Mono',
#  'CACATGAGTTTCGACA-1': 'CD4 Memory T',
#  'CACCAAAAGGACATCG-1': 'CD16 Mono',
#  'CACCGTTCACCCTAGG-1': 'CD4 Naive T',
#  'CACGAATCACATAGCT-1': 'CD4 Memory T',
#  'CACGAATTCAAGTCGT-1': 'CD4 Memory T',
#  'CACGGGTAGCATTTGC-1': 'CD14 Mono',
#  'CACGGGTTCCCGATCT-1': 'B',
#  'CACGTTCCAGCTTCCT-1': 'CD14 Mono',
#  'CACGTTCTCTATCACT-1': 'CD4 Memory T',
#  'CACTAAGGTGATAGTA-1': 'CD8 T',
#  'CACTGAAGTCTTTCTA-1': 'B',
#  'CACTGAATCCTGATAG-1': 'DC',
#  'CACTGGGAGGCGACAT-1': 'CD14 Mono',
#  'CACTGGGAGTTACTCG-1': 'CD14 Mono',
#  'CACTGGGGTCGCACAC-1': 'CD16 Mono',
#  'CACTGTCCACATATGC-1': 'B',
#  'CACTTCGTCACCTACC-1': 'CD14 Mono',
#  'CAGAGCCGTGCCCGTA-1': 'CD4 Naive T',
#  'CAGATACTCGTTCCCA-1': 'T activated',
#  'CAGATTGAGCTGAGCA-1': 'CD4 Memory T',
#  'CAGATTGGTGACTAAA-1': 'B',
#  'CAGCAATGTATCGTTG-1': 'CD16 Mono',
#  'CAGCAGCTCAGAGTTC-1': 'CD8 T',
#  'CAGCCAGGTGGGTTGA-1': 'CD16 Mono',
#  'CAGCGTGTCCATCACC-1': 'B',
#  'CAGGCCAGTTCAATCG-1': 'CD4 Memory T',
#  'CAGGCCATCACTCACC-1': 'CD8 T',
#  'CAGGCCATCCACTAGA-1': 'CD14 Mono',
#  'CAGGGCTAGATTGGGC-1': 'CD8 T',
#  'CAGGGCTTCGACGAGA-1': 'B activated',
#  'CAGGTATGTCAGTCTA-1': 'DC',
#  'CAGGTATGTGTAAATG-1': 'B',
#  'CAGTTCCCAATCGTCA-1': 'CD8 T',
#  'CATAAGCGTAGCGCTC-1': 'CD4 Naive T',
#  'CATAAGCTCCGTGTGG-1': 'CD14 Mono',
#  'CATACTTTCAACGAGG-1': 'CD4 Memory T',
#  'CATCAAGGTATGGTTC-1': 'B',
#  'CATCAAGGTTGTCCCT-1': 'B',
#  'CATCCGTGTATCGCTA-1': 'CD4 Naive T',
#  'CATCGGGTCGCTACAA-1': 'B',
#  'CATCGTCTCCGTTGAA-1': 'CD8 T',
#  'CATGAGTCACCATTCC-1': 'CD8 T',
#  'CATGCCTCAATTGCTG-1': 'B',
#  'CATGCCTGTTCCGCAG-1': 'CD14 Mono',
#  'CATTCTAGTAGCTTGT-1': 'CD4 Memory T',
#  'CATTCTATCAGTAGGG-1': 'CD14 Mono',
#  'CATTGAGAGGGACCAT-1': 'CD16 Mono',
#  'CATTTCATCTCTCTTC-1': 'CD14 Mono',
#  'CCAAGCGAGCTAATCC-1': 'CD4 Naive T',
#  'CCAAGCGAGGTTCATC-1': 'CD14 Mono',
#  'CCAATGAAGGTCACTT-1': 'B',
#  'CCAATTTCAAAGGCTG-1': 'CD8 T',
#  'CCAATTTCATTCGATG-1': 'CD8 T',
#  'CCACACTCAGGACTTT-1': 'CD16 Mono',
#  'CCACCATAGGTCATCT-1': 'CD8 T',
#  'CCACGAGTCTTCCTAA-1': 'CD14 Mono',
#  'CCACGTTTCATCAGTG-1': 'B',
#  'CCACGTTTCGTGAGAG-1': 'CD4 Naive T',
#  'CCACGTTTCTGCTGAA-1': 'B',
#  'CCACTTGTCGCAGAGA-1': 'CD16 Mono',
#  'CCATAAGGTGAGGAAA-1': 'CD14 Mono',
#  'CCATCACCATTAAAGG-1': 'B',
#  'CCATCACTCTAACACG-1': 'CD14 Mono',
#  'CCCGGAATCAAACCCA-1': 'CD4 Naive T',
#  'CCCTAACCAGGTTCGC-1': 'CD4 Naive T',
#  'CCCTAACGTAACTGCT-1': 'CD16 Mono',
#  'CCCTTAGGTTTCCAAG-1': 'CD4 Memory T',
#  'CCGAACGAGCTAAGTA-1': 'Mk',
#  'CCGAACGAGGAACGCT-1': 'DC',
#  'CCGATCTGTGGAGGTT-1': 'CD14 Mono',
#  'CCGATGGGTTCTCGCT-1': 'DC',
#  'CCGATGGTCTGTCGCT-1': 'B',
#  'CCGCAAGCATTCAGGT-1': 'CD4 Naive T',
#  'CCGCAAGGTACCAGAG-1': 'CD8 T',
#  'CCGGACAGTGATACCT-1': 'CD16 Mono',
#  'CCGGGTACACTCCGAG-1': 'DC',
#  'CCGGTAGGTAGTACGG-1': 'NK',
#  'CCGTAGGGTTCCCACT-1': 'NK',
#  'CCGTAGGTCATACAGC-1': 'B',
#  'CCGTGAGAGAGGTCAC-1': 'CD8 T',
#  'CCGTGAGTCGCCTTTG-1': 'B',
#  'CCGTTCACAGAAGCTG-1': 'CD8 T',
#  'CCTAAGAAGACTCTAC-1': 'T activated',
#  'CCTATCGAGACAGCGT-1': 'CD14 Mono',
#  'CCTCAACTCTTAGCCC-1': 'CD4 Naive T',
#  'CCTCAGTCATGATGCT-1': 'CD4 Naive T',
#  'CCTCAGTTCCGAGCTG-1': 'B',
#  'CCTCATGCACTATGTG-1': 'NK',
#  'CCTCATGGTTTCGCTC-1': 'CD4 Naive T',
#  'CCTCATGTCTCTCAAT-1': 'CD14 Mono',
#  'CCTCCAAAGGCCCGTT-1': 'DC',
#  'CCTCCAACAACCCTCT-1': 'CD8 T',
#  'CCTCCAACACAATGAA-1': 'B',
#  'CCTCCTCAGTCCCGAC-1': 'B',
#  'CCTCCTCCATTCAGGT-1': 'CD4 Naive T',
#  'CCTCCTCTCAAGCGTT-1': 'CD4 Naive T',
#  'CCTCTAGCAGACCTAT-1': 'CD14 Mono',
#  'CCTCTCCTCGTTCCTG-1': 'CD14 Mono',
#  'CCTGCATAGTGGTGAC-1': 'DC',
#  'CCTGCATCAACGGGTA-1': 'CD4 Naive T',
#  'CCTGCATGTTCTTAGG-1': 'CD4 Memory T',
#  'CCTGTTGGTGTGCCTG-1': 'CD14 Mono',
#  'CCTGTTGTCAAGAGTA-1': 'B',
#  'CCTTCAGAGGAACGTC-1': 'Mk',
#  'CCTTCAGCACAGAGCA-1': 'B',
#  'CGAAGGATCGACGCGT-1': 'CD8 T',
#  'CGAATTGGTCTGTTAG-1': 'CD4 Naive T',
#  'CGAGAAGTCAAGTTGC-1': 'B activated',
#  'CGAGAAGTCCAATGCA-1': 'DC',
#  'CGAGGAAAGTCGCGAA-1': 'CD4 Naive T',
#  'CGAGGAACACTGATTG-1': 'B',
#  'CGAGGCTCAGATCACT-1': 'B',
#  'CGAGGCTCAGCATGCC-1': 'CD14 Mono',
#  'CGAGTGCGTTCCGCGA-1': 'CD4 Memory T',
#  'CGAGTTAGTCGAGTTT-1': 'CD14 Mono',
#  'CGATCGGCAATTGGTC-1': 'CD14 Mono',
#  'CGATCGGCAGCGTGAA-1': 'CD4 Naive T',
#  'CGATGCGAGCAGAAAG-1': 'CD4 Naive T',
#  'CGATGCGTCGAACCAT-1': 'B',
#  'CGATGGCCACTCGATA-1': 'CD8 T',
#  'CGATGGCGTAGCGTCC-1': 'CD4 Memory T',
#  'CGCAGGTGTGCTTCAA-1': 'B',
#  'CGCATAAAGTGATGGC-1': 'CD14 Mono',
#  'CGCGTGAGTACAATAG-1': 'B',
#  'CGGAACCGTATCACGT-1': 'CD14 Mono',
#  'CGGAACCGTTTGCAGT-1': 'B',
#  'CGGACACAGGACAGCT-1': 'CD14 Mono',
#  'CGGGACTGTTTCACTT-1': 'NK',
#  'CGGGTGTTCCGTGACG-1': 'Mk',
#  'CGTAAGTGTGATAGTA-1': 'CD8 T',
#  'CGTAGTATCAGCCCAG-1': 'CD8 T',
#  'CGTCAAACAGAATGTA-1': 'NK',
#  'CGTCCATGTTTGGAAA-1': 'CD4 Naive T',
#  'CGTGAATAGTCGGCCT-1': 'CD4 Memory T',
#  'CGTGCTTAGCTTTGTG-1': 'CD14 Mono',
#  'CGTGCTTCAAGCGCTC-1': 'CD14 Mono',
#  'CGTGCTTGTTTAGACC-1': 'T activated',
#  'CGTGTCTCACAGTACT-1': 'CD4 Memory T',
#  'CGTGTCTCATGGGTTT-1': 'CD4 Memory T',
#  'CGTGTCTGTCAGTTTG-1': 'CD16 Mono',
#  'CGTTAGATCAGCCTCT-1': 'CD16 Mono',
#  'CGTTAGATCATTATCC-1': 'Mk',
#  'CGTTAGATCCAAGAGG-1': 'CD14 Mono',
#  'CGTTCTGTCAGCGCAC-1': 'CD4 Memory T',
#  'CGTTCTGTCCCGAACG-1': 'NK',
#  'CTAACCCAGCCGCTTG-1': 'CD4 Naive T',
#  'CTAACCCCACTTCAAG-1': 'CD4 Memory T',
#  'CTAAGTGCACAATGCT-1': 'B',
#  'CTAAGTGGTCCACTCT-1': 'CD8 T',
#  'CTACAGACAACAAAGT-1': 'B activated',
#  'CTACCTGTCTCGAACA-1': 'CD14 Mono',
#  'CTACGGGTCGTTCAGA-1': 'CD8 T',
#  'CTAGACAGTCTAACTG-1': 'CD16 Mono',
#  'CTAGGTATCTAACGCA-1': 'B',
#  'CTATCCGAGCTGTTAC-1': 'CD4 Naive T',
#  'CTCAACCGTGGATGAC-1': 'B',
#  'CTCAACCGTGTGTCGC-1': 'B',
#  'CTCAAGAAGATTACCC-1': 'CD4 Naive T',
#  'CTCAAGAGTCAAAGAT-1': 'NK',
#  'CTCAATTTCGGAAGGT-1': 'CD14 Mono',
#  'CTCACTGCACCTTCCA-1': 'CD4 Naive T',
#  'CTCAGGGGTCATCGCG-1': 'CD14 Mono',
#  'CTCAGGGTCTCACCCA-1': 'CD16 Mono',
#  'CTCAGTCAGGGACAGG-1': 'NK',
#  'CTCATCGAGAGGCGTT-1': 'CD4 Naive T',
#  'CTCATCGTCGTACCTC-1': 'B',
#  'CTCATTAAGGAAGTGA-1': 'CD14 Mono',
#  'CTCATTATCGTACACA-1': 'DC',
#  'CTCCAACCAATCTCTT-1': 'CD8 T',
#  'CTCCAACGTAGTGTGG-1': 'CD4 Memory T',
#  'CTCCATGAGACAGCTG-1': 'B',
#  'CTCCATGGTGTTGACT-1': 'CD14 Mono',
#  'CTCCATGTCATCGTAG-1': 'CD4 Naive T',
#  'CTCCATGTCGTCGATA-1': 'CD14 Mono',
#  'CTCCCAATCAATCAGC-1': 'NK',
#  'CTCCCTCAGCGCGTTC-1': 'Mk',
#  'CTCCCTCCACCGGAAA-1': 'NK',
#  'CTCCCTCGTTTACGAC-1': 'CD8 T',
#  'CTCCCTCTCATCGCTC-1': 'CD8 T',
#  'CTCCGATTCCTTTAGT-1': 'CD8 T',
#  'CTCCGATTCTTTCTAG-1': 'CD4 Naive T',
#  'CTCCTCCTCACCTCTG-1': 'CD4 Naive T',
#  'CTCCTTTAGATGCTGG-1': 'DC',
#  'CTCCTTTTCTACACTT-1': 'CD4 Naive T',
#  'CTCGAGGAGCCTATTG-1': 'B',
#  'CTCGAGGAGGAAAGGT-1': 'CD8 T',
#  'CTCTCAGGTTAAGCAA-1': 'CD4 Naive T',
#  'CTCTCGATCCATAGGT-1': 'B',
#  'CTCTGGTAGTAGGATT-1': 'CD14 Mono',
#  'CTGAATGAGCTCTATG-1': 'CD14 Mono',
#  'CTGAATGAGGCGAACT-1': 'CD4 Naive T',
#  'CTGAGGCGTTCAGCGC-1': 'B',
#  'CTGATCCGTCGCGTCA-1': 'CD8 T',
#  'CTGATCCTCCCTCTAG-1': 'CD8 T',
#  'CTGCAGGAGCCATTGT-1': 'CD4 Memory T',
#  'CTGCATCAGCGTCAAG-1': 'CD14 Mono',
#  'CTGCATCGTAAGCTCT-1': 'CD4 Naive T',
#  'CTGCCATTCAGTGTTG-1': 'CD4 Memory T',
#  'CTGCCATTCGGAACTT-1': 'CD14 Mono',
#  'CTGCCTACAAGACTGG-1': 'CD14 Mono',
#  'CTGCCTATCTTGATTC-1': 'B',
#  'CTGCGAGAGATTAGAC-1': 'CD14 Mono',
#  'CTGCGAGAGTGCACTT-1': 'CD14 Mono',
#  'CTGCGAGCAGATTCGT-1': 'B',
#  'CTGCGAGGTAGGTTTC-1': 'CD14 Mono',
#  'CTGCTCACAGCGTTTA-1': 'CD16 Mono',
#  'CTGGACGCAACGATTC-1': 'CD4 Memory T',
#  'CTGGACGCACACGGTC-1': 'CD14 Mono',
#  'CTGGACGGTTCCCAAA-1': 'CD8 T',
#  'CTGGACGTCTCATTTG-1': 'CD16 Mono',
#  'CTGGCAGTCGTCTCAC-1': 'CD4 Naive T',
#  'CTGTCGTAGCTGGCCT-1': 'CD4 Naive T',
#  'CTGTGAAAGGAACGCT-1': 'CD14 Mono',
#  'CTGTGAATCATCGCTC-1': 'CD14 Mono',
#  'CTGTGGGGTCGTGATT-1': 'B activated',
#  'CTTAGGAGTCTGTGGC-1': 'B',
#  'CTTCAATGTTGGACTT-1': 'CD4 Naive T',
#  'CTTCGGTCACGTTCGG-1': 'B',
#  'CTTCGGTTCCAAGAGG-1': 'B',
#  'CTTCTCTTCCTACAAG-1': 'CD8 T',
#  'CTTGAGAAGAATTGCA-1': 'CD4 Naive T',
#  'CTTGATTAGGTAGGCT-1': 'CD4 Memory T',
#  'GAACACTGTTGGACTT-1': 'B',
#  'GAACGTTGTCAGGAGT-1': 'CD16 Mono',
#  'GAACTGTCATCGAACT-1': 'CD4 Naive T',
#  'GAACTGTTCTCAAAGC-1': 'CD4 Memory T',
#  'GAAGAATAGGTACAAT-1': 'CD14 Mono',
#  'GAAGCCCCAGGAACCA-1': 'CD16 Mono',
#  'GAAGCGATCAGTAGGG-1': 'CD8 T',
#  'GAAGGACGTCTGCCTT-1': 'CD14 Mono',
#  'GAAGGGTTCGCAGATT-1': 'CD4 Memory T',
#  'GAAGTAAGTCTAGATC-1': 'CD4 Memory T',
#  'GAATCACCAGTGGTGA-1': 'CD8 T',
#  'GACACGCCAGTCCGTG-1': 'B',
#  'GACACGCGTTCCAAAC-1': 'B',
#  'GACAGCCGTATCGTGT-1': 'CD8 T',
#  'GACCCTTCAGCGTATT-1': 'CD16 Mono',
#  'GACCCTTCATCATCTT-1': 'CD4 Naive T',
#  'GACCTTCCACCTGCGA-1': 'CD14 Mono',
#  'GACCTTCGTCGAGCTC-1': 'CD4 Naive T',
#  'GACTATGCATCATTGG-1': 'CD14 Mono',
#  'GACTATGTCCAAGGGA-1': 'CD4 Memory T',
#  'GACTCAATCTCCCAAC-1': 'CD14 Mono',
#  'GACTGATTCATCCTAT-1': 'CD4 Naive T',
#  'GACTTCCTCCTCTAGC-1': 'T activated',
#  'GAGAAATCATTGGATC-1': 'T activated',
#  'GAGACCCAGTAGGATT-1': 'CD14 Mono',
#  'GAGACTTAGTCACTCA-1': 'NK',
#  'GAGACTTCAGGCTATT-1': 'CD14 Mono',
#  'GAGAGGTTCATAGACC-1': 'CD4 Naive T',
#  'GAGATGGCATGTAACC-1': 'CD4 Naive T',
#  'GAGCCTGAGGCAGCTA-1': 'pDC',
#  'GAGCCTGCAGTCTCTC-1': 'CD8 T',
#  'GAGCCTGGTCCACGCA-1': 'CD4 Memory T',
#  'GAGCTGCGTCGGATTT-1': 'CD14 Mono',
#  'GAGGCAAAGTCACGAG-1': 'CD4 Memory T',
#  'GAGGGATCACTTGGCG-1': 'CD4 Naive T',
#  'GAGGGTACAGTTTCAG-1': 'CD4 Memory T',
#  'GAGGGTAGTCAACACT-1': 'CD4 Naive T',
#  'GAGGGTATCTGTCCCA-1': 'CD4 Memory T',
#  'GAGTGAGGTCGGCTAC-1': 'B',
#  'GAGTGTTCACAAGCTT-1': 'B',
#  'GAGTGTTGTACGTAGG-1': 'CD8 T',
#  'GAGTTACAGACGACGT-1': 'CD4 Naive T',
#  'GAGTTGTAGCGTTACT-1': 'CD14 Mono',
#  'GAGTTGTAGTGCGTCC-1': 'CD14 Mono',
#  'GAGTTGTCACGGTGCT-1': 'CD8 T',
#  'GATAGCTGTCGGAAAC-1': 'DC',
#  'GATAGCTGTCTGTTAG-1': 'CD4 Memory T',
#  'GATAGCTTCGTGCAGC-1': 'B',
#  'GATCACACACCCTGTT-1': 'B activated',
#  'GATCAGTAGGAACATT-1': 'B',
#  'GATCAGTAGTGCGCTC-1': 'CD4 Naive T',
#  'GATCATGAGGCCTAAG-1': 'CD4 Memory T',
#  'GATCCCTAGAGGATGA-1': 'CD4 Naive T',
#  'GATCCCTGTAATTAGG-1': 'CD4 Naive T',
#  'GATCGTACAGCGCGTT-1': 'CD4 Memory T',
#  'GATCGTATCTCTGGTC-1': 'NK',
#  'GATGACTTCGTGGCGT-1': 'CD4 Naive T',
#  'GATGACTTCTCTAGGA-1': 'B',
#  'GATGAGGCAAATGCGG-1': 'CD4 Naive T',
#  'GATGATCGTATGGAAT-1': 'CD4 Memory T',
#  'GATGATCGTGTAACGG-1': 'B',
#  'GATGCTAGTACAGGTG-1': 'CD4 Naive T',
#  'GATGGAGAGCCAGACA-1': 'B',
#  'GATGGAGCACTTGAAC-1': 'CD4 Memory T',
#  'GATGGAGTCTGCGGCA-1': 'CD4 Naive T',
#  'GATGGAGTCTTCCAGC-1': 'CD14 Mono',
#  'GATTCTTGTACAGTCT-1': 'CD8 T',
#  'GATTGGTGTTGAGAGC-1': 'CD4 Memory T',
#  'GATTTCTCAAGTGGGT-1': 'CD8 T',
#  'GATTTCTTCCTTCAGC-1': 'B',
#  'GCAACCGTCATTTCCA-1': 'CD8 T',
#  'GCAACCGTCGAACGGA-1': 'B',
#  'GCACGGTAGTAGTCTC-1': 'CD4 Memory T',
#  'GCACGGTCACCCAACG-1': 'B',
#  'GCACGTGTCAGACATC-1': 'NK',
#  'GCAGCCAAGAGGTCAC-1': 'B',
#  'GCAGCCACATACATCG-1': 'B',
#  'GCAGCCAGTTGCGTAT-1': 'B',
#  'GCAGCCATCACCGGGT-1': 'NK',
#  'GCAGCTGGTAAGTTAG-1': 'DC',
#  'GCAGCTGGTGGGTCAA-1': 'B',
#  'GCAGCTGTCAAAGCCT-1': 'pDC',
#  'GCAGCTGTCCTTCTGG-1': 'NK',
#  'GCAGTTACACATTCTT-1': 'CD14 Mono',
#  'GCAGTTATCTCTCTTC-1': 'CD16 Mono',
#  'GCATCGGGTAACGATA-1': 'CD14 Mono',
#  'GCCAACGTCTAACGCA-1': 'NK',
#  'GCCAACGTCTGCATAG-1': 'CD14 Mono',
#  'GCCAGGTGTTAGAAAC-1': 'CD4 Naive T',
#  'GCCAGTGAGTCCTACA-1': 'B',
#  'GCCGATGAGTAACCTC-1': 'CD4 Naive T',
#  'GCCGATGCATCTTTCA-1': 'B',
#  'GCCGTGACAACGACTT-1': 'CD14 Mono',
#  'GCCGTGACATGCCGGT-1': 'CD8 T',
#  'GCCGTGAGTCAGTCCG-1': 'Mk',
#  'GCCTGTTCACAGTCAT-1': 'CD16 Mono',
#  'GCGAGAAAGTTGTAGA-1': 'CD16 Mono',
#  'GCGAGAATCCTCAGAA-1': 'CD4 Naive T',
#  'GCGGAAAGTGTGTCCG-1': 'CD8 T',
#  'GCGGATCAGCAACTTC-1': 'CD14 Mono',
#  'GCTACCTCACGCACCA-1': 'CD14 Mono',
#  'GCTACCTGTCCTACAA-1': 'CD14 Mono',
#  'GCTGAATAGCACTCTA-1': 'B',
#  'GCTGAATCACACGGAA-1': 'B',
#  'GCTGAATTCGTTAGTG-1': 'CD14 Mono',
#  'GCTGCAGAGGGCAGAG-1': 'B',
#  'GCTGCAGGTGCTGATT-1': 'CD4 Naive T',
#  'GCTGCAGGTTGACGGA-1': 'CD14 Mono',
#  'GCTGGGTAGTACAACA-1': 'NK',
#  'GCTTCACCAACACGAG-1': 'DC',
#  'GCTTGGGAGAAGGTAG-1': 'CD16 Mono',
#  'GCTTTCGAGTGCAAAT-1': 'CD14 Mono',
#  'GCTTTCGGTTCGGGTC-1': 'CD4 Naive T',
#  'GCTTTCGTCCGGTAGC-1': 'CD4 Memory T',
#  'GCTTTCGTCTGGGTCG-1': 'CD16 Mono',
#  'GGAACCCAGCCATTTG-1': 'CD14 Mono',
#  'GGAACCCTCTAATTCC-1': 'B',
#  'GGAAGTGCAACCCTCT-1': 'CD14 Mono',
#  'GGAATCTCAAACTGCT-1': 'CD4 Naive T',
#  'GGAATCTTCAATCTCT-1': 'CD4 Memory T',
#  'GGAATGGAGGACTAAT-1': 'CD16 Mono',
#  'GGAATGGCACGACGCT-1': 'CD4 Naive T',
#  'GGACGTCGTTCAACGT-1': 'CD14 Mono',
#  'GGAGAACGTGCCCACA-1': 'CD14 Mono',
#  'GGAGGATGTATGAAAC-1': 'CD14 Mono',
#  'GGAGGTAAGGCGTTGA-1': 'CD14 Mono',
#  'GGAGGTATCTGGTGCG-1': 'CD14 Mono',
#  'GGATCTATCACCTACC-1': 'CD8 T',
#  'GGATCTATCATAAGGA-1': 'CD8 T',
#  'GGATGTTAGCCGGATA-1': 'CD4 Memory T',
#  'GGCGTCACATTGTGCA-1': 'CD8 T',
#  'GGCTGTGCACGGTGAA-1': 'B',
#  'GGCTGTGGTCCACATA-1': 'Mk',
#  'GGCTTGGCACCGAATT-1': 'B',
#  'GGCTTGGGTAGATCGG-1': 'B',
#  'GGCTTGGTCTTCTTCC-1': 'CD14 Mono',
#  'GGGACAATCCGATCTC-1': 'DC',
#  'GGGACCTGTTCTTGTT-1': 'CD4 Naive T',
#  'GGGACTCCACATATCG-1': 'CD4 Naive T',
#  'GGGACTCCACGGGCTT-1': 'DC',
#  'GGGAGATCACGGGTAA-1': 'CD4 Naive T',
#  'GGGAGATTCACGGACC-1': 'B',
#  'GGGAGTAAGCAGGCAT-1': 'CD16 Mono',
#  'GGGAGTATCACCTCGT-1': 'DC',
#  'GGGAGTATCTTAGCCC-1': 'CD14 Mono',
#  'GGGATCCAGGGCAATC-1': 'NK',
#  'GGGATGAAGGGAGGGT-1': 'CD4 Naive T',
#  'GGGATGAAGTCCCGAC-1': 'CD4 Memory T',
#  'GGGCCATTCAGACCGC-1': 'CD14 Mono',
#  'GGGCTACAGACCAAAT-1': 'T activated',
#  'GGGCTACAGGCAGTCA-1': 'CD4 Naive T',
#  'GGGCTCATCGCAATTG-1': 'CD8 T',
#  'GGGTAGAAGTAGGGTC-1': 'CD4 Naive T',
#  'GGGTCACCAGGAGGTT-1': 'CD4 Memory T',
#  'GGGTCACGTCCTTAAG-1': 'DC',
#  'GGGTCACTCACAAGGG-1': 'CD14 Mono',
#  'GGGTCTGGTTTGAAAG-1': 'CD8 T',
#  'GGGTCTGTCCCGTTCA-1': 'CD14 Mono',
#  'GGGTGAACATAAGCAA-1': 'CD4 Naive T',
#  'GGGTTATCAGCCATTA-1': 'CD4 Memory T',
#  'GGGTTTACACAGAGCA-1': 'CD14 Mono',
#  'GGGTTTACACTAAACC-1': 'B',
#  'GGTAATCCAAAGGAGA-1': 'CD8 T',
#  'GGTAATCCACAGCATT-1': 'CD16 Mono',
#  'GGTAATCCATACCACA-1': 'CD14 Mono',
#  'GGTAATCTCAAGTTGC-1': 'DC',
#  'GGTAGAGAGACCAGCA-1': 'CD14 Mono',
#  'GGTCACGCAATGGCCC-1': 'CD4 Naive T',
#  'GGTCACGGTCGTGATT-1': 'CD4 Naive T',
#  'GGTCTGGTCAGACATC-1': 'B',
#  'GGTCTGGTCTCCCAAC-1': 'CD8 T',
#  'GGTGATTAGCTGTACT-1': 'B',
#  'GGTGATTCAGCTCGGT-1': 'CD14 Mono',
#  'GGTGGCTGTGCGCTCA-1': 'NK',
#  'GGTGTCGCAACGATCT-1': 'CD14 Mono',
#  'GGTGTCGGTGTTATCG-1': 'B',
#  'GGTGTTAGTGGATTTC-1': 'B activated',
#  'GGTTCTCCAGGTTCCG-1': 'CD14 Mono',
#  'GGTTGTATCGAAGGAC-1': 'pDC',
#  'GTAACACAGCTCCGAC-1': 'CD16 Mono',
#  'GTAACACGTAGATGTA-1': 'CD8 T',
#  'GTAAGTCTCGATTGGT-1': 'CD4 Naive T',
#  'GTAATCGCAGTTTCGA-1': 'CD8 T',
#  'GTAATCGGTTGCGAAG-1': 'NK',
#  'GTAATGCCACCAGTAT-1': 'CD14 Mono',
#  'GTACAACAGATAGCTA-1': 'NK',
#  'GTAGAAACATGGACAG-1': 'CD14 Mono',
#  'GTAGAAATCTGAGATC-1': 'CD14 Mono',
#  'GTAGAGGCAACTTCTT-1': 'CD4 Naive T',
#  'GTAGATCCATCCCGTT-1': 'CD4 Memory T',
#  'GTAGCTATCTCATGGA-1': 'CD14 Mono',
#  'GTAGGAGTCCGTCACT-1': 'NK',
#  'GTAGGTTCAGAAGCGT-1': 'CD4 Naive T',
#  'GTAGGTTGTGTTCGTA-1': 'CD8 T',
#  'GTAGTACCACCCTATC-1': 'DC',
#  'GTAGTACTCTGTGTGA-1': 'DC',
#  'GTATTTCAGAAGAGCA-1': 'CD4 Naive T',
#  'GTCAAACCAAGCACCC-1': 'CD4 Memory T',
#  'GTCACGGAGCGGGTTA-1': 'CD4 Naive T',
#  'GTCACGGCACCGTACG-1': 'CD4 Memory T',
#  'GTCACTCTCTTGAACG-1': 'CD4 Naive T',
#  'GTCATGAAGTTTGGCT-1': 'CD14 Mono',
#  'GTCATGACATTGGATC-1': 'B',
#  'GTCATTTCAAGAGAGA-1': 'CD4 Naive T',
#  'GTCATTTTCCTAGAGT-1': 'NK',
#  'GTCCCATCATGCCGAC-1': 'CD4 Naive T',
#  'GTCCTCAAGTCACGAG-1': 'B',
#  'GTCGAATAGGAGTATT-1': 'B',
#  'GTCGAATCAGAACCGA-1': 'CD14 Mono',
#  'GTCGAATGTCAAGCGA-1': 'CD14 Mono',
#  'GTCGCGAAGCAGCGAT-1': 'CD8 T',
#  'GTCGCGAGTTTACCTT-1': 'NK',
#  'GTCTACCCAGGAAGTC-1': 'CD4 Naive T',
#  'GTCTAGAGTATGTCAC-1': 'DC',
#  'GTCTAGATCGAGAGAC-1': 'B',
#  'GTCTGTCAGATACGAT-1': 'CD4 Naive T',
#  'GTCTGTCTCGAGCCTG-1': 'NK',
#  'GTGAGCCGTGATCGTT-1': 'NK',
#  'GTGAGCCTCTGGAAGG-1': 'CD14 Mono',
#  'GTGAGGAAGCATTGAA-1': 'CD4 Memory T',
#  'GTGAGGACACAACATC-1': 'CD8 T',
#  'GTGAGGACACTTTAGG-1': 'CD4 Naive T',
#  'GTGAGTTTCCAATGCA-1': 'CD4 Memory T',
#  'GTGATGTAGACATCAA-1': 'pDC',
#  'GTGCGTGAGCTTCTAG-1': 'CD14 Mono',
#  'GTGCTGGCAGGCTACC-1': 'NK',
#  'GTGCTGGTCAAACCTG-1': 'CD4 Naive T',
#  'GTGCTTCAGACCATAA-1': 'CD14 Mono',
#  'GTGCTTCCACTCATAG-1': 'NK',
#  'GTGCTTCGTCGCTTGG-1': 'CD14 Mono',
#  'GTGGAAGAGCCAAGTG-1': 'B',
#  'GTGGCGTAGAATAACC-1': 'CD8 T',
#  'GTGGCGTCAATCGAAA-1': 'CD8 T',
#  'GTGGGAAAGGTCGTAG-1': 'B',
#  'GTGGGAACATGAGTAA-1': 'CD4 Memory T',
#  'GTGGTTAAGTAACCGG-1': 'CD4 Memory T',
#  'GTGTAACTCTTGGTGA-1': 'CD4 Naive T',
#  'GTGTCCTAGTCGGCCT-1': 'NK',
#  'GTGTCCTCAGTTGTTG-1': 'B',
#  'GTGTCCTGTGGCCTCA-1': 'CD4 Naive T',
#  'GTGTGATCACTACGGC-1': 'CD4 Memory T',
#  'GTGTGATTCTTACGTT-1': 'NK',
#  'GTGTGGCAGGTACTGG-1': 'DC',
#  'GTGTGGCAGGTAGTCG-1': 'CD8 T',
#  'GTGTGGCTCACCACAA-1': 'CD4 Naive T',
#  'GTGTTCCAGGTGCCTC-1': 'B',
#  'GTGTTCCGTAGTTCCA-1': 'Mk',
#  'GTTACAGAGTGTAGTA-1': 'CD4 Naive T',
#  'GTTACAGCAAATCAGA-1': 'CD4 Memory T',
#  'GTTACGAGTATGAGAT-1': 'CD14 Mono',
#  'GTTAGTGAGAACGTGC-1': 'CD4 Memory T',
#  'GTTAGTGCACCTCTAC-1': 'CD14 Mono',
#  'GTTCCGTAGTTGCCCG-1': 'CD14 Mono',
#  'GTTCCGTCACCCGTAG-1': 'CD8 T',
#  'GTTCTATCAAATGAGT-1': 'B',
#  'GTTCTATCACGTGTGC-1': 'CD14 Mono',
#  'GTTCTATTCTACACTT-1': 'NK',
#  'GTTGAACAGGAACATT-1': 'NK',
#  'GTTGAACGTACCCGCA-1': 'Mk',
#  'GTTGCGGAGCTGCCTG-1': 'CD4 Naive T',
#  'GTTGCTCAGTTTCGAC-1': 'NK',
#  'GTTGCTCTCATTTCCA-1': 'CD4 Memory T',
#  'GTTGTAGCAGTTCTAG-1': 'NK',
#  'GTTGTGATCTCGGTCT-1': 'CD4 Naive T',
#  'GTTTGGAGTGTATACC-1': 'CD4 Naive T',
#  'TAACGACCACATATGC-1': 'CD4 Naive T',
#  'TAACTTCGTTGTGGAG-1': 'NK',
#  'TAAGCACAGAAGCTGC-1': 'CD4 Memory T',
#  'TAAGCACTCACCATAG-1': 'B',
#  'TAAGCCATCTGGCCTT-1': 'B',
#  'TAAGCGTTCGTTGCCT-1': 'B',
#  'TAAGCGTTCTGTCGTC-1': 'CD4 Naive T',
#  'TAATTCCCACTCCGGA-1': 'CD8 T',
#  'TAATTCCGTATTGACC-1': 'CD16 Mono',
#  'TAATTCCGTCAGTCCG-1': 'T activated',
#  'TACAACGCAAAGGTTA-1': 'CD4 Naive T',
#  'TACAACGCATAGATCC-1': 'CD4 Memory T',
#  'TACACCCTCGACTCCT-1': 'CD4 Naive T',
#  'TACAGGTTCCTTACCG-1': 'CD4 Naive T',
#  'TACATTCGTGGCTTAT-1': 'CD4 Memory T',
#  'TACCTCGCACCCAACG-1': 'CD4 Naive T',
#  'TACCTGCAGTCTGCAT-1': 'CD4 Memory T',
#  'TACCTGCTCCAAGCTA-1': 'B',
#  'TACGCTCTCTCGGTCT-1': 'DC',
#  'TACGCTCTCTTAAGGC-1': 'B',
#  'TACGGGCTCAACGAGG-1': 'CD4 Naive T',
#  'TACGGGCTCTACCACC-1': 'CD4 Naive T',
#  'TACGTCCCAAGTGATA-1': 'CD14 Mono',
#  'TACTTCATCATGCCGG-1': 'CD8 T',
#  'TAGACTGAGATTGTGA-1': 'B',
#  'TAGACTGGTCTTGAAC-1': 'CD14 Mono',
#  'TAGACTGTCGCCGAGT-1': 'CD14 Mono',
#  'TAGAGTCGTTGTGTAC-1': 'CD14 Mono',
#  'TAGATCGCAAATGGTA-1': 'CD14 Mono',
#  'TAGATCGCACACGCCA-1': 'CD4 Naive T',
#  'TAGATCGTCACAACCA-1': 'CD14 Mono',
#  'TAGCACAAGTACTCGT-1': 'CD14 Mono',
#  'TAGGAGGCAAGACCTT-1': 'B',
#  'TAGGAGGGTTCCAGGC-1': 'B',
#  'TAGGGTTAGAGAGCGG-1': 'CD4 Naive T',
#  'TAGGGTTAGGAACATT-1': 'B',
#  'TAGGTACGTGTCATCA-1': 'CD14 Mono',
#  'TAGGTACTCGAAGCAG-1': 'NK',
#  'TAGTGCACACTCGATA-1': 'CD14 Mono',
#  'TAGTGCACAGAGGAAA-1': 'CD14 Mono',
#  'TATACCTGTTCTCGTC-1': 'CD8 T',
#  'TATACCTTCTGTCCGT-1': 'CD14 Mono',
#  'TATATCCCATGCGTGC-1': 'B',
#  'TATCGCCTCTCCCAAC-1': 'DC',
#  'TATCTTGTCCATCTCG-1': 'DC',
#  'TATGTTCAGTATGGAT-1': 'CD8 T',
#  'TATTGCTTCTCGAACA-1': 'NK',
#  'TCAAGCATCCACTTTA-1': 'CD4 Naive T',
#  'TCAATCTAGAGGTTTA-1': 'T activated',
#  'TCAATCTGTTTCCCAC-1': 'B',
#  'TCACAAGGTAGTGGCA-1': 'CD4 Naive T',
#  'TCACAAGGTGGATACG-1': 'CD14 Mono',
#  'TCACACCCACCAGCCA-1': 'CD16 Mono',
#  'TCACACCGTCTCACGG-1': 'CD8 T',
#  'TCACACCGTTAAACCC-1': 'DC',
#  'TCACACCTCTGGGAGA-1': 'CD4 Memory T',
#  'TCACACCTCTTACCAT-1': 'CD8 T',
#  'TCACATTCAGAACTAA-1': 'CD16 Mono',
#  'TCACATTCATGCCATA-1': 'CD4 Memory T',
#  'TCACGCTAGGACATCG-1': 'CD8 T',
#  'TCACGCTGTCTGCCTT-1': 'CD4 Naive T',
#  'TCACGCTTCACTAGCA-1': 'CD4 Naive T',
#  'TCACGCTTCGGACTGC-1': 'CD4 Memory T',
#  'TCACGGGCAACCGACC-1': 'CD14 Mono',
#  'TCACTATGTTTAGACC-1': 'CD8 T',
#  'TCACTCGCAAAGCAAT-1': 'CD14 Mono',
#  'TCACTCGGTCAACCAT-1': 'CD4 Naive T',
#  'TCACTCGTCGGTCATA-1': 'CD16 Mono',
#  'TCAGCAACAAATCAAG-1': 'CD16 Mono',
#  'TCAGCAAGTATGACAA-1': 'DC',
#  'TCAGGGCTCATGCGGC-1': 'CD4 Naive T',
#  'TCAGGTACAATCGCAT-1': 'B',
#  'TCAGGTAGTATGGTAA-1': 'CD4 Memory T',
#  'TCAGTCCGTAAGATCA-1': 'DC',
#  'TCAGTCCGTCTCTCAC-1': 'CD4 Memory T',
#  'TCAGTTTAGGATATAC-1': 'CD16 Mono',
#  'TCATACTCAGGTACGA-1': 'CD8 T',
#  'TCATACTTCAGAGCAG-1': 'CD8 T',
#  'TCATATCCATGCTGCG-1': 'pDC',
#  'TCATCATAGCACACAG-1': 'CD14 Mono',
#  'TCATCATGTTGCACGC-1': 'CD14 Mono',
#  'TCATCCGTCCAACTGA-1': 'B',
#  'TCATGCCCAAAGCGTG-1': 'CD8 T',
#  'TCATGCCGTGTCTTAG-1': 'CD4 Naive T',
#  'TCATGTTAGAGGCGGA-1': 'B',
#  'TCATGTTGTGTGTGTT-1': 'CD4 Naive T',
#  'TCATTACGTGCATGAG-1': 'CD8 T',
#  'TCATTGTGTGAGCAGT-1': 'CD4 Naive T',
#  'TCCATCGGTTTAGTCG-1': 'B',
#  'TCCCACACAGACCAAG-1': 'CD14 Mono',
#  'TCCCAGTAGACCGTTT-1': 'CD14 Mono',
#  'TCCCAGTTCGACATAC-1': 'CD14 Mono',
#  'TCCCATGTCGGCCCAA-1': 'CD4 Naive T',
#  'TCCGATCTCAAACCTG-1': 'CD4 Memory T',
#  'TCCTCCCAGTCTAACC-1': 'CD14 Mono',
#  'TCCTCGATCTCTCGAC-1': 'CD8 T',
#  'TCCTCTTAGAGTGAAG-1': 'CD14 Mono',
#  'TCCTCTTAGCCAAGGT-1': 'DC',
#  'TCCTTCTCAACTCGTA-1': 'DC',
#  'TCCTTTCTCGCTGTCT-1': 'pDC',
#  'TCGAAGTGTATCAGGG-1': 'CD8 T',
#  'TCGACCTCAAAGACTA-1': 'CD4 Naive T',
#  'TCGACCTCAAGTAGTA-1': 'B activated',
#  'TCGACGGTCGAAGTGG-1': 'CD4 Memory T',
#  'TCGATTTGTACGCTTA-1': 'CD8 T',
#  'TCGCAGGAGATTGACA-1': 'CD8 T',
#  'TCGCAGGGTAGGCTCC-1': 'CD4 Naive T',
#  'TCGCAGGGTTCTAACG-1': 'CD4 Naive T',
#  'TCGCTCACAAGATTGA-1': 'CD4 Naive T',
#  'TCGCTTGAGAGACAAG-1': 'CD8 T',
#  'TCGCTTGAGCATTTGC-1': 'NK',
#  'TCGGGACTCTAGATCG-1': 'CD4 Naive T',
#  'TCGGGCACAGTTACCA-1': 'CD4 Naive T',
#  'TCGGGCATCCGATTAG-1': 'CD4 Memory T',
#  'TCGGGCATCTGAACGT-1': 'CD14 Mono',
#  'TCGGGTGCAGTCTGGC-1': 'CD14 Mono',
#  'TCGGTCTTCATTGCTT-1': 'CD4 Memory T',
#  'TCGGTCTTCGACATAC-1': 'T activated',
#  'TCGTAGACAATGAAAC-1': 'CD14 Mono',
#  'TCGTGCTGTAAGGAGA-1': 'CD4 Naive T',
#  'TCGTGCTGTGATCATC-1': 'pDC',
#  'TCTACCGCAGTCGTTA-1': 'CD4 Memory T',
#  'TCTACCGTCCACGGAC-1': 'CD4 Naive T',
#  'TCTATACGTTATCCAG-1': 'CD14 Mono',
#  'TCTATCAGTATGCTAC-1': 'CD14 Mono',
#  'TCTCACGAGGCTCCCA-1': 'CD8 T',
#  'TCTCCGAAGTCAATCC-1': 'DC',
#  'TCTCCGATCTCTCTTC-1': 'B',
#  'TCTCTGGCAAAGCAAT-1': 'CD16 Mono',
#  'TCTGCCAGTAACGCGA-1': 'CD4 Naive T',
#  'TCTGCCAGTAGATGTA-1': 'CD14 Mono',
#  'TCTGGCTCATCCTGTC-1': 'CD4 Naive T',
#  'TCTGTCGAGACTAGAT-1': 'CD14 Mono',
#  'TCTGTCGCACCAGCGT-1': 'NK',
#  'TCTTAGTAGGCCTGCT-1': 'CD4 Naive T',
#  'TCTTAGTCAACACGAG-1': 'DC',
#  'TCTTAGTGTTGCCAAT-1': 'CD14 Mono',
#  'TCTTAGTTCAGAATAG-1': 'CD8 T',
#  'TCTTGCGAGATGAAGG-1': 'CD4 Memory T',
#  'TCTTGCGCACTACTTT-1': 'B',
#  'TCTTGCGCAGAGGAAA-1': 'CD4 Memory T',
#  'TCTTGCGGTCCAGCCA-1': 'T activated',
#  'TCTTTGAGTGGAGAAA-1': 'B',
#  'TGAACGTCAAATGAAC-1': 'CD8 T',
#  'TGAACGTGTAACTAAG-1': 'CD4 Naive T',
#  'TGAATGCGTGGACTAG-1': 'B',
#  'TGAATGCTCGACGAGA-1': 'CD14 Mono',
#  'TGAATGCTCGCCGTGA-1': 'CD14 Mono',
#  'TGACAGTTCGAGATGG-1': 'B',
#  'TGACCCTTCTCATTGT-1': 'CD16 Mono',
#  'TGACGCGGTGGCTTAT-1': 'CD14 Mono',
#  'TGACTCCAGTCTCCTC-1': 'CD4 Naive T',
#  'TGACTCCCACCATAAC-1': 'CD14 Mono',
#  'TGAGACTAGGCTGAAC-1': 'CD4 Naive T',
#  'TGAGCATTCCATTGCC-1': 'CD8 T',
#  'TGAGCATTCCTTCACG-1': 'CD4 Naive T',
#  'TGAGCATTCGATACTG-1': 'CD4 Naive T',
#  'TGAGCATTCTGTCTCG-1': 'DC',
#  'TGAGCGCCACTATGTG-1': 'CD14 Mono',
#  'TGAGCGCCAGCATACT-1': 'DC',
#  'TGAGCGCTCGTCTAAG-1': 'CD8 T',
#  'TGAGGAGTCCATCGTC-1': 'B',
#  'TGAGGGATCAAACGTC-1': 'B',
#  'TGAGGTTCAAACTAGA-1': 'CD14 Mono',
#  'TGAGGTTCAGGACATG-1': 'DC',
#  'TGAGGTTGTAGCTTTG-1': 'DC',
#  'TGAGTCACAGAACGCA-1': 'CD14 Mono',
#  'TGAGTCAGTAACCCTA-1': 'CD8 T',
#  'TGAGTCAGTCACTCTC-1': 'CD14 Mono',
#  'TGATCAGAGGATTCAA-1': 'DC',
#  'TGATGCACAGGGCTTC-1': 'CD8 T',
#  'TGATGGTAGACCCGCT-1': 'CD8 T',
#  'TGCACGGTCGAGTACT-1': 'B',
#  'TGCAGGCAGCGTTCAT-1': 'CD4 Memory T',
#  'TGCAGGCCAGGAATAT-1': 'CD4 Naive T',
#  'TGCAGTAAGTAGTCCT-1': 'B',
#  'TGCAGTATCCACATAG-1': 'CD16 Mono',
#  'TGCATCCCACCCAACG-1': 'B',
#  'TGCATGAAGCACCCAC-1': 'CD4 Naive T',
#  'TGCGACGAGCGACAGT-1': 'NK',
#  'TGCGATAAGAATCGCG-1': 'CD8 T',
#  'TGCGGCAAGTGGTGAC-1': 'CD8 T',
#  'TGCGGCACAAAGACGC-1': 'CD4 Naive T',
#  'TGCTCCACAATCTAGC-1': 'CD8 T',
#  'TGCTCGTAGACGAGCT-1': 'CD4 Naive T',
#  'TGCTCGTTCCCATTTA-1': 'B',
#  'TGCTGAACAGCACAAG-1': 'CD8 T',
#  'TGCTTCGCATAGCTGT-1': 'CD14 Mono',
#  'TGCTTGCGTGAACTAA-1': 'CD4 Naive T',
#  'TGGAACTAGCGTCTCG-1': 'CD16 Mono',
#  'TGGAGAGCAGTCAGTT-1': 'CD14 Mono',
#  'TGGAGGAAGTAGGAAG-1': 'CD16 Mono',
#  'TGGATCAGTTCTCCCA-1': 'CD14 Mono',
#  'TGGATGTTCACGGGAA-1': 'CD8 T',
#  'TGGGAAGTCGATTGGT-1': 'CD8 T',
#  'TGGGAGAAGCAAGTGC-1': 'B',
#  'TGGGAGAAGTGGTGGT-1': 'CD14 Mono',
#  'TGGGATTAGTCACGAG-1': 'NK',
#  'TGGGATTGTACGATGG-1': 'DC',
#  'TGGGCGTAGTGGAATT-1': 'B',
#  'TGGGCTGAGAGGGTCT-1': 'CD4 Memory T',
#  'TGGGCTGAGCGTTAGG-1': 'CD16 Mono',
#  'TGGGCTGCATCCGATA-1': 'CD8 T',
#  'TGGGCTGGTCGCGGTT-1': 'NK',
#  'TGGGTTAGTATTGAGA-1': 'CD16 Mono',
#  'TGGGTTAGTGCACGCT-1': 'B',
#  'TGGGTTATCAGTAGGG-1': 'CD14 Mono',
#  'TGGTACACAAAGGGTC-1': 'CD4 Naive T',
#  'TGGTAGTCAGGCATGA-1': 'CD4 Naive T',
#  'TGGTAGTCATCACAGT-1': 'CD4 Naive T',
#  'TGGTAGTTCCCTCATG-1': 'CD14 Mono',
#  'TGTACAGAGACTCGAG-1': 'CD14 Mono',
#  'TGTACAGAGTGAGTTA-1': 'CD14 Mono',
#  'TGTACAGGTGGATTTC-1': 'CD4 Naive T',
#  'TGTAGACTCCATTTAC-1': 'CD14 Mono',
#  'TGTCAGACAACTTGGT-1': 'CD4 Memory T',
#  'TGTCAGACACTCACTC-1': 'T activated',
#  'TGTCCACCAACTGGTT-1': 'CD8 T',
#  'TGTCCACTCGCTTACC-1': 'pDC',
#  'TGTCCCAAGCTCCATA-1': 'CD8 T',
#  'TGTCCCAAGGTCATAA-1': 'B',
#  'TGTCCCACATACTTTC-1': 'CD4 Naive T',
#  ...}

# %%
#map back onto raw adata
adata = sc.read_h5ad('/content/pbmc.h5ad')
adata.var_names_make_unique()

# %%
adata.obs['cell_type'] = adata.obs.index.map(cell_mapper)
adata.obs
# Out:
#                        cell_type
# Cells
# AAACCCAAGGAGAGTA-1     CD14 Mono
# AAACGCTTCAGCCCAG-1             B
# AAAGAACAGACGACTG-1         CD8 T
# AAAGAACCAATGGCAG-1         CD8 T
# AAAGAACGTCTGCAAT-1  CD4 Memory T
# ...                          ...
# TTTCCTCTCTCTTGCG-1     CD16 Mono
# TTTGATCTCTTTGGAG-1   CD4 Naive T
# TTTGGTTAGTAACCTC-1         CD8 T
# TTTGGTTGTAGAATAC-1     CD14 Mono
# TTTGTTGCAATTAGGA-1             B
#
# [1087 rows x 1 columns]

# %%
import numpy as np
def pp(adata):
    sc.pp.filter_cells(adata, min_genes=200) #get rid of cells with fewer than 200 genes
    sc.pp.filter_genes(adata, min_cells=3) #get rid of genes that are found in fewer than 3 cells
    adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
    sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)
    upper_lim = np.quantile(adata.obs.n_genes_by_counts.values, .98)
    lower_lim = np.quantile(adata.obs.n_genes_by_counts.values, .02)
    adata = adata[(adata.obs.n_genes_by_counts < upper_lim) & (adata.obs.n_genes_by_counts > lower_lim)]
    adata = adata[adata.obs.pct_counts_mt < 20]
    sc.pp.normalize_total(adata, target_sum=1e4) #normalize every cell to 10,000 UMI
    sc.pp.log1p(adata) #change to log counts
    sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5) #these are default values
    adata.raw = adata #save raw data before processing values and further filtering
    adata = adata[:, adata.var.highly_variable] #filter highly variable
    sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt']) #Regress out effects of total counts per cell and the percentage of mitochondrial genes expressed
    sc.pp.scale(adata, max_value=10) #scale each gene to unit variance
    sc.tl.pca(adata, svd_solver='arpack')
    sc.pp.neighbors(adata, n_neighbors=10, n_pcs=20)
    sc.tl.umap(adata)
    return adata

# %%
adata = pp(adata)
# Out:
# /usr/local/lib/python3.8/dist-packages/scanpy/preprocessing/_normalization.py:170: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /usr/local/lib/python3.8/dist-packages/anndata/_core/anndata.py:1235: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c

# %%
sc.pl.umap(adata, color = 'cell_type')
# Out:
# /usr/local/lib/python3.8/dist-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
with rc_context({'figure.figsize': (4, 4)}):
    sc.pl.umap(adata, color = 'CD3E')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-b6fe5cf11b36> in <module>
# ----> 1 with rc_context({'figure.figsize': (4, 4)}):
#       2     sc.pl.umap(adata, color = 'CD3E')
#
# NameError: name 'rc_context' is not defined

# %%
import scanpy as sc
import pandas as pd
from matplotlib.pyplot import rc_context

# %%
ax = sc.pl.umap(adata, show = False)

sc.pl.umap(adata[adata.obs.cell_type.str.contains('NK')], palette = ['red'], color = 'cell_type', ax = ax)

# %%
sc.pl.umap(adata, color = 'CD3E')

# %%
# compute clusters using the leiden method and store the results with the name `clusters`
sc.tl.leiden(adata, key_added='clusters', resolution=0.5)

# %%
with rc_context({'figure.figsize': (5, 5)}):
    sc.pl.umap(adata, color='clusters', add_outline=True, legend_loc='on data',
               legend_fontsize=12, legend_fontoutline=2,frameon=False,
               title='clustering of cells', palette='Set1')
# Out:
# /usr/local/lib/python3.8/dist-packages/scanpy/plotting/_tools/scatterplots.py:369: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(
# /usr/local/lib/python3.8/dist-packages/scanpy/plotting/_tools/scatterplots.py:379: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(
# /usr/local/lib/python3.8/dist-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata, color='cell_type', legend_loc='on data',
           frameon=False, legend_fontsize=10, legend_fontoutline=2)
# Out:
# /usr/local/lib/python3.8/dist-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
with rc_context({'figure.figsize': (4.5, 3)}):
    sc.pl.violin(adata, ['CD79A', 'MS4A1'], groupby='clusters' )

# %%
marker_genes_dict = {
    'B-cell': ['CD79A', 'MS4A1'],
    'Dendritic': ['FCER1A', 'CST3'],
    'Monocytes': ['FCGR3A'],
    'NK': ['GNLY', 'NKG7'],

    'T-cell': ['CD3D'],
}

# %%
ax = sc.pl.heatmap(adata, marker_genes_dict, groupby='clusters', cmap='viridis', dendrogram=True)
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_clusters). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: 0, 1, 2, etc.
# var_group_labels: B-cell, Dendritic, Monocytes, etc.

# %%
ax = sc.pl.heatmap(adata, marker_genes_dict, groupby='clusters', layer='scaled', vmin=-2, vmax=2, cmap='RdBu_r', dendrogram=True, swap_axes=True, figsize=(11,4))
# Out:
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: 0, 1, 2, etc.
# var_group_labels: B-cell, Dendritic, Monocytes, etc.

# %%
ax = sc.pl.tracksplot(adata, marker_genes_dict, groupby='clusters', dendrogram=True)
# Out:
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: 0, 1, 2, etc.
# var_group_labels: B-cell, Dendritic, Monocytes, etc.
